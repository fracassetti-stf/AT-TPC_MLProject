# %% [markdown]
# First the necessary python packages are imported

# %%
import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D # <--- This is important for 3d plotting 
import h5py
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import (accuracy_score, confusion_matrix, f1_score, 
                             matthews_corrcoef, roc_curve, roc_auc_score, classification_report)

from helper_functions import *

# %% [markdown]
# ### Random Seed
# Fix the numpy random seed for repeatable results.

# %%
np.random.seed(42)

# %% [markdown]
# Now the dataset is loaded.
# Default location (for me) is in DataFiles folder (located in current directory)
#
# So file path is ./DataFiles/Mg22_alphaalpha_digiSim.h5

# %%
#URL for downloading from the Machine Learning ECT github (somehow does not work)
#f.close()
#data_origin_MLECT = 'https://github.com/NuclearTalent/MachineLearningECT/raw/master/doc/ProjectsExercises/2020/ProjectAT/pdf/Mg22_alphaalpha_digiSim.h5'
#MLECT_path = tf.keras.utils.get_file('Mg22_alphaalpha_digiSim.h5', origin=data_origin_MLECT)
#f=h5py.File(MLECT_path, 'r')

# %%
#Open the local file
local_data='./DataFiles/Mg22_alphaalpha_digiSim.h5'
f=h5py.File(local_data, 'r')

# Print the keys of the h5 file: each event is a key "Event_[#event]"
# print(f.keys()) # show all the keys

# How many events (keys)?
print(len(f.keys()))

# Print some events info
print(f['Event_[0]'])
print(f['Event_[1]'])
print(f['Event_[2]'])
print(f['Event_[3]'])

# Let's see the content of "Event_[0]"
f['Event_[0]'][:]



### Extra, not used 
# AllEvents = np.zeros (len(f.keys()))
# Out:
# 2000
# <HDF5 dataset "Event_[0]": shape (24,), type "|V48">
# <HDF5 dataset "Event_[1]": shape (195,), type "|V48">
# <HDF5 dataset "Event_[2]": shape (24,), type "|V48">
# <HDF5 dataset "Event_[3]": shape (124,), type "|V48">
# array([(-2.45412970e+00,  1.45075214, 834., 417, 6.73360577e+03, 0),
#        (-1.33514404e-05,  2.79990482, 834., 417, 1.25854633e+04, 0),
#        (-2.45412970e+00, -1.45075214, 834., 417, 1.70520808e+03, 0),
#        ( 2.45413303e+00, -1.45075214, 900., 450, 3.77884522e+03, 0),
#        (-1.33514404e-05, -2.79990482, 900., 450, 1.13686783e+04, 0),
#        ( 2.45413303e+00,  1.45075214, 962., 481, 3.21076480e+03, 0),
#        ( 4.90825081e+00, -5.70140886, 964., 482, 4.45706507e+01, 0),
#        ( 2.45410442e+00,  7.05056143, 966., 483, 2.11128009e+01, 0),
#        (-2.45413113e+00, -7.05056143, 984., 492, 1.90553867e+01, 0),
#        (-4.90824747e+00,  5.70140886, 986., 493, 1.97473273e+01, 0),
#        ( 4.90825081e+00,  5.70140886, 986., 493, 2.12675051e+01, 0),
#        (-4.90824747e+00,  2.79990482, 990., 495, 4.76823698e+01, 0),
#        (-4.90824747e+00, -5.70140886, 990., 495, 2.12226325e+01, 0),
#        (-4.90824747e+00, -2.79990482, 990., 495, 2.63826991e+02, 0),
#        ( 4.90825081e+00,  2.79990482, 990., 495, 4.01348998e+02, 0),
#        (-2.45413113e+00,  7.05056143, 990., 495, 2.26033067e+01, 0),
#        (-1.33514404e-05,  5.70140886, 992., 496, 4.18758660e+02, 0),
#        ( 2.45410442e+00, -7.05056143, 992., 496, 5.55712714e+01, 0),
#        ( 7.36236858e+00,  1.45075214, 996., 498, 9.16391397e+00, 0),
#        (-1.33514404e-05, -5.70140886, 996., 498, 2.33806124e+02, 0),
#        ( 4.90825081e+00, -2.79990482, 996., 498, 1.83987018e+02, 0),
#        (-7.36236525e+00,  1.45075214, 998., 499, 8.28173405e+01, 0),
#        ( 7.36236858e+00, -1.45075214, 998., 499, 2.62758505e+01, 0),
#        (-7.36236525e+00, -1.45075214, 998., 499, 1.74805170e+01, 0)],
#       dtype={'names':['x','y','z','t','A','trackID'], 'formats':['<f8','<f8','<f8','<i4','<f8','<i4'], 'offsets':[0,8,16,24,32,40], 'itemsize':48})

# %% [markdown]
# Now we load the data into a simple list. This list has three indices [event number][pad fired][data column]
#
# with event number in [0,1999], pad fired in [0,x] with x variable for each event, data column in [0,5] (x,y,z,T,A,zeros)

# %%
# Converting the data in a python list: AllDataList = [ [x0,y0,z0,t0,A0,0], [],[]...]
AllDataList = []
for i in range(len(f.keys())):
    KeyString = "Event_[" + str(i) +"]"
    AllDataList.append(f[KeyString][:])
    
# Printing Event_[0]
print(AllDataList[0])
# Checking that the conversion is correct
# The two following rows should be equal
print(f["Event_[0]"][0])
print(AllDataList[0][0])

# Lenght of the List
print("Dataset contains " + str(len(AllDataList)) + " events")
# Out:
# [(-2.45412970e+00,  1.45075214, 834., 417, 6.73360577e+03, 0)
#  (-1.33514404e-05,  2.79990482, 834., 417, 1.25854633e+04, 0)
#  (-2.45412970e+00, -1.45075214, 834., 417, 1.70520808e+03, 0)
#  ( 2.45413303e+00, -1.45075214, 900., 450, 3.77884522e+03, 0)
#  (-1.33514404e-05, -2.79990482, 900., 450, 1.13686783e+04, 0)
#  ( 2.45413303e+00,  1.45075214, 962., 481, 3.21076480e+03, 0)
#  ( 4.90825081e+00, -5.70140886, 964., 482, 4.45706507e+01, 0)
#  ( 2.45410442e+00,  7.05056143, 966., 483, 2.11128009e+01, 0)
#  (-2.45413113e+00, -7.05056143, 984., 492, 1.90553867e+01, 0)
#  (-4.90824747e+00,  5.70140886, 986., 493, 1.97473273e+01, 0)
#  ( 4.90825081e+00,  5.70140886, 986., 493, 2.12675051e+01, 0)
#  (-4.90824747e+00,  2.79990482, 990., 495, 4.76823698e+01, 0)
#  (-4.90824747e+00, -5.70140886, 990., 495, 2.12226325e+01, 0)
#  (-4.90824747e+00, -2.79990482, 990., 495, 2.63826991e+02, 0)
#  ( 4.90825081e+00,  2.79990482, 990., 495, 4.01348998e+02, 0)
#  (-2.45413113e+00,  7.05056143, 990., 495, 2.26033067e+01, 0)
#  (-1.33514404e-05,  5.70140886, 992., 496, 4.18758660e+02, 0)
#  ( 2.45410442e+00, -7.05056143, 992., 496, 5.55712714e+01, 0)
#  ( 7.36236858e+00,  1.45075214, 996., 498, 9.16391397e+00, 0)
#  (-1.33514404e-05, -5.70140886, 996., 498, 2.33806124e+02, 0)
#  ( 4.90825081e+00, -2.79990482, 996., 498, 1.83987018e+02, 0)
#  (-7.36236525e+00,  1.45075214, 998., 499, 8.28173405e+01, 0)
#  ( 7.36236858e+00, -1.45075214, 998., 499, 2.62758505e+01, 0)
#  (-7.36236525e+00, -1.45075214, 998., 499, 1.74805170e+01, 0)]
# (-2.4541297, 1.45075214, 834., 417, 6733.60577268, 0)
# (-2.4541297, 1.45075214, 834., 417, 6733.60577268, 0)
# Dataset contains 2000 events

# %% [markdown]
# The last data column contains only zeroes and can be removed to reduce data size

# %% [markdown]
#  ### Labeling and cleaning
#  The events came labeled, with even nr events = reaction (label 1), odd nr events = beam (label 0)
#
#  We also remove empty events (384, 430,484,914,1204 (numbers correspond to keys))
#
# Before moving on we label the data and then split it into training, validation and test (only generating indices)
# We also remove the empty events and label these correctly

# %%
# Label "0"(beam) or "1"(reaction)
LabelsList = []

# List of not empy Events
AllData = []

for i in range(len(AllDataList)):
    if (len(AllDataList[i])>0): # cleaning empty events
        AllData.append(AllDataList[i])
        if (i%2==0): # Assigning labels to the events
            LabelsList.append(1)
        else:
            LabelsList.append(0)
            
# AllData is the list of not empty events, 
# LabelsList is the list of the labels
 
# Converting a list into a numpy array
Labels = np.array(LabelsList)

# Printing    
print(Labels)
print("Dataset contains " + str(len(AllData)) + " non-empty events")

# The result is a nparray [0,1,...,1995]
x_idx = np.arange(len(AllData))

# 
trainval_idx, test_idx, not_used1, not_used2 = train_test_split(x_idx, x_idx, test_size = 0.10)
train_idx, val_idx, not_used3, not_used4 = train_test_split(trainval_idx, trainval_idx, test_size = 0.10)
print("Dataset was divided into " + str(len(train_idx)) + " training events, " + str(len(val_idx)) + " validation events and " + str(len(test_idx)) + " test events")
# Out:
# [1 0 1 ... 0 1 0]
# Dataset contains 1995 non-empty events
# Dataset was divided into 1615 training events, 180 validation events and 200 test events

# %% [markdown]
# ### Raw event visualization
# We plot a few events using the helper function plot_3d_event to get an idea of beam and reaction events.

# %%
plot_3d_event(AllData,Labels,0)
plot_3d_event(AllData,Labels,1)
plot_3d_event(AllData,Labels,2)
plot_3d_event(AllData,Labels,3)
plot_3d_event(AllData,Labels,4)
plot_3d_event(AllData,Labels,5)

# %% [markdown]
# ### Simple Characteristics
# Now let's try to visualize simple characteristics, average x, average y, average z and sum of A for each event
# Also number of pads fired per event
#
# 2nd version: replacing average x, average y by standard deviation x, standard deviation y.

# %%
MeanXPerEvent = np.zeros(len(AllData))
MeanYPerEvent = np.zeros(len(AllData))
MeanZPerEvent = np.zeros(len(AllData))
SumAPerEvent = np.zeros(len(AllData))
PadsPerEvent = np.zeros(len(AllData))
MeanWeightedXPerEvent = np.zeros(len(AllData))
MeanWeightedYPerEvent = np.zeros(len(AllData))
StDevXPerEvent = np.zeros(len(AllData))
StDevYPerEvent = np.zeros(len(AllData))
StDevZPerEvent = np.zeros(len(AllData))



for i in range(len(AllData)):

    for j in range(len(AllData[i])):
        MeanXPerEvent[i] = MeanXPerEvent[i] + AllData[i][j][0]
        MeanYPerEvent[i] = MeanYPerEvent[i] + AllData[i][j][1]
        MeanZPerEvent[i] = MeanZPerEvent[i] + AllData[i][j][2]
        SumAPerEvent[i] = SumAPerEvent[i] + AllData[i][j][4]
        MeanWeightedXPerEvent[i] = MeanWeightedXPerEvent[i] + AllData[i][j][0]*AllData[i][j][4]
        MeanWeightedYPerEvent[i] = MeanWeightedYPerEvent[i] + AllData[i][j][1]*AllData[i][j][4]
    
    MeanXPerEvent[i] = MeanXPerEvent[i]/len(AllData[i])
    MeanYPerEvent[i] = MeanYPerEvent[i]/len(AllData[i])
    MeanZPerEvent[i] = MeanZPerEvent[i]/len(AllData[i])
    MeanWeightedXPerEvent[i] = MeanWeightedXPerEvent[i]/len(AllData[i])
    MeanWeightedYPerEvent[i] = MeanWeightedYPerEvent[i]/len(AllData[i])
    
    #second for loop for calculation of standard deviation
    for j in range(len(AllData[i])):
        StDevXPerEvent[i] = StDevXPerEvent[i] + (AllData[i][j][0]-MeanXPerEvent[i])**2
        StDevYPerEvent[i] = StDevYPerEvent[i] + (AllData[i][j][1]-MeanYPerEvent[i])**2
        StDevZPerEvent[i] = StDevZPerEvent[i] + (AllData[i][j][2]-MeanZPerEvent[i])**2
   
    StDevXPerEvent[i] = np.sqrt(StDevXPerEvent[i])/(len(AllData[i])-1)
    StDevYPerEvent[i] = np.sqrt(StDevYPerEvent[i])/(len(AllData[i])-1)
    StDevZPerEvent[i] = np.sqrt(StDevZPerEvent[i])/(len(AllData[i])-1)
    
    
        
    
    
    PadsPerEvent[i] = len(AllData[i])
    
print(SumAPerEvent)
print(MeanXPerEvent)
# Out:
# [ 41292.86413493 322786.82279782  89094.2067578  ...  37851.88599835
#   45542.97047786 260079.24714189]
# [-3.33786011e-06 -6.60346445e+01 -3.33786011e-06 ... -4.39459217e+00
#  -3.33786011e-06 -4.74462833e+00]

# %%
fig, ax = plt.subplots(3, 2, figsize=(14, 18))

#define legend for 2d plots
from matplotlib.lines import Line2D
legend_elements = [Line2D([0], [0], marker='o', color='w', label='Beam', markerfacecolor='purple', markersize=15),
                   Line2D([0], [0], marker='o', color='w', label='Reaction', markerfacecolor='yellow', markersize=15)]

ax[0][0].scatter(MeanXPerEvent[train_idx],MeanYPerEvent[train_idx], c = Labels[train_idx])
ax[0][0].set_title("mean X vs mean Y per event")
ax[0][0].set_xlabel("X")
ax[0][0].set_ylabel("Y")
ax[0][0].legend(handles=legend_elements)

ax[0][1].scatter(MeanXPerEvent[train_idx],MeanZPerEvent[train_idx], c = Labels[train_idx])
ax[0][1].set_title("mean X vs mean Z per event")
ax[0][1].set_xlabel("X")
ax[0][1].set_ylabel("Z")
ax[0][1].legend(handles=legend_elements)

ax[1][0].hist(SumAPerEvent[Labels>0.5], color='blue', label = 'Reaction', histtype = 'step')
ax[1][0].hist(SumAPerEvent[Labels<0.5], color='orange', label = 'Beam', histtype = 'step')
ax[1][0].set_title("Charge Deposition histogram")
ax[1][0].set_xlabel("Charge")
ax[1][0].set_ylabel("Counts")
ax[1][0].legend()

ax[1][1].hist(PadsPerEvent[Labels>0.5], color='blue', label = 'Reaction', histtype = 'step')
ax[1][1].hist(PadsPerEvent[Labels<0.5], color='orange', label = 'Beam', histtype = 'step')
ax[1][1].set_title("Histogram of Pads Fired per Event")
ax[1][1].set_xlabel("Number of Pads")
ax[1][1].set_ylabel("Counts")
ax[1][1].legend()

ax[2][0].scatter(PadsPerEvent[train_idx],SumAPerEvent[train_idx], c = Labels[train_idx])
ax[2][0].set_title("number of pads vs sum charge per event")
ax[2][0].set_xlabel("Number of Pads")
ax[2][0].set_ylabel("Charge")
ax[2][0].legend(handles=legend_elements)



ax[2][1].scatter(StDevXPerEvent[train_idx],StDevYPerEvent[train_idx], c = Labels[train_idx])
ax[2][1].set_title("standard deviation X vs standard deviation y per event")
ax[2][1].set_xlabel("stdev X")
ax[2][1].set_ylabel("stdev Y")
ax[2][1].legend(handles=legend_elements)

# %% [markdown]
# ### Visualizing the outliers
#
# Looking at the previous plots, one notes a few reaction events that behave very much as beam events
# We find and plot them here

# %%
large_x_stdev = train_idx[StDevXPerEvent[train_idx]>3]
Outliers = []
for i in range(len(large_x_stdev)):
    if (Labels[large_x_stdev[i]]==1):
        Outliers.append(large_x_stdev[i])

print(Outliers)
for i in range(len(Outliers)):
    plot_3d_event(AllData,Labels,Outliers[i])
# Out:
# [1711, 499, 280, 1098]

# %% [markdown]
# ### Merging
# Now we merge these data into features and labels.

# %%
xSimple = np.zeros((len(AllData),5))

for i in range(len(AllData)):
    #standard x and y
    xSimple[i][0] = MeanXPerEvent[i]
    xSimple[i][1] = MeanYPerEvent[i]
    #alternative x and y
    #xSimple[i][0] = StDevXPerEvent[i]
    #xSimple[i][1] = StDevYPerEvent[i]
    xSimple[i][2] = MeanZPerEvent[i]
    xSimple[i][3] = SumAPerEvent[i]
    xSimple[i][4] = PadsPerEvent[i]


xSimple_train = xSimple[train_idx][:]
xSimple_val = xSimple[val_idx][:]
xSimple_test = xSimple[test_idx][:]
Labels_train = Labels[train_idx]
Labels_val = Labels[val_idx]
Labels_test = Labels[test_idx]

#ar_nan = np.where(np.isnan(xSimple))
#print (ar_nan)
#ar_inf = np.where(np.isinf(xSimple))
#print (ar_inf)
#ar_neginf = np.where(np.isneginf(xSimple))
#print (ar_neginf)

print(xSimple[1204,:])
# Out:
# [ 2.91426647e+00 -8.01214222e+00  6.32156250e+02  1.72528081e+05
#   6.40000000e+01]

# %% [markdown]
# ### Logistic Regression
# Now let us try a few simple models on the parameters obtained above. We start with a logistic regression model, as imported from sklearn.

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(xSimple_train, Labels_train)
print("validation set accuracy: {:.3f}".format(logreg.score(xSimple_val,Labels_val)))
# Out:
# validation set accuracy: 0.967

# %% [markdown]
# Another try using StandardScaler to get scaled data.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(xSimple_train)
xSimple_train_stsc = scaler.transform(xSimple_train)
xSimple_val_stsc = scaler.transform(xSimple_val)
logreg2 = LogisticRegression()
logreg2.fit(xSimple_train_stsc, Labels_train)
print("validation set accuracy: {:.3f}".format(logreg2.score(xSimple_val_stsc,Labels_val)))

LR_pred_train = logreg2.predict(xSimple_train_stsc)
LR_pred_val = logreg2.predict(xSimple_val_stsc)

accuracy = accuracy_score(Labels_val, LR_pred_val)
confmat = confusion_matrix(Labels_val, LR_pred_val)
f1 = f1_score(Labels_val, LR_pred_val)
mcc = matthews_corrcoef(Labels_val, LR_pred_val)

accuracy_train = accuracy_score(Labels_train, LR_pred_train)
confmat_train = confusion_matrix(Labels_train, LR_pred_train)
f1_train = f1_score(Labels_train, LR_pred_train)
mcc_train = matthews_corrcoef(Labels_train, LR_pred_train)

print("Confusion matrix for training set:\n")
plot_confusion_matrix(Labels_train, LR_pred_train, ["beam","reaction"])
print("Accuracy:", accuracy_train)
print("F1-score:", f1_train)
print("MCC:", mcc_train)


print("Confusion matrix for validation set:\n")
plot_confusion_matrix(Labels_val, LR_pred_val, ["beam","reaction"])
print("Accuracy:", accuracy)
print("F1-score:", f1)
print("MCC:", mcc)
# Out:
# validation set accuracy: 0.994
# Confusion matrix for training set:
# Accuracy: 0.9938080495356038
# F1-score: 0.9938875305623472
# MCC: 0.9876140048408917
# Confusion matrix for validation set:
# Accuracy: 0.9944444444444445
# F1-score: 0.9942857142857142
# MCC: 0.9889417905532354

# %% [markdown]
# ### Random Forest
# Here a random forest is used for classification. Grid search is used for optimisation of the parameters

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
#RFC = RandomForestClassifier()
#RFC.fit(xSimple_train_stsc, Labels_train)

#RFC_pred_train = RFC.predict(xSimple_train_stsc)
#RFC_mse_train = mean_squared_error(Labels_train, RFC_pred_train)
#RFC_rmse_train = np.sqrt(RFC_mse_train)
#print('random forest rmse of training data is: ', RFC_rmse_train)

#scores = cross_val_score(RFC, xSimple_train_stsc, Labels_train, scoring="neg_mean_squared_error", cv=10)
#RFC_scores = np.sqrt(-scores)
#display_scores(RFC_scores)


param_grid = [
{'n_estimators': [3, 4,5,6], 'max_features': [2,3,4,5], 'bootstrap': [False,True]},
]
RFC = RandomForestClassifier()
grid_search_imp = GridSearchCV(RFC, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search_imp.fit(xSimple_train_stsc, Labels_train)
print(grid_search_imp.best_params_)
print(grid_search_imp.best_estimator_)

cvres = grid_search_imp.cv_results_
#for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    #print(np.sqrt(-mean_score), params)

feature_importances = grid_search_imp.best_estimator_.feature_importances_
print(sorted(zip(feature_importances, ["x","y","z","charge","nrofpads"]), reverse=True))

RFC_best = grid_search_imp.best_estimator_
RFC_pred_train = RFC_best.predict(xSimple_train_stsc)
RFC_pred_val = RFC_best.predict(xSimple_val_stsc)
#forest_mse_imp_final = mean_squared_error(trdata_labels, deaths_predictions_forest_final)
#forest_rmse_imp_final = np.sqrt(forest_mse_imp_final)
#print('random forest rmse (final version) of training data is: ', forest_rmse_imp)

accuracy = accuracy_score(Labels_val, RFC_pred_val)
confmat = confusion_matrix(Labels_val, RFC_pred_val)
f1 = f1_score(Labels_val, RFC_pred_val)
mcc = matthews_corrcoef(Labels_val, RFC_pred_val)

accuracy_train = accuracy_score(Labels_train, RFC_pred_train)
confmat_train = confusion_matrix(Labels_train, RFC_pred_train)
f1_train = f1_score(Labels_train, RFC_pred_train)
mcc_train = matthews_corrcoef(Labels_train, RFC_pred_train)

print("Confusion matrix for training set:\n")
plot_confusion_matrix(Labels_train, RFC_pred_train, ["beam","reaction"])
print("Accuracy:", accuracy_train)
print("F1-score:", f1_train)
print("MCC:", mcc_train)
print(RFC_pred_train)

print("Confusion matrix for validation set:\n")
plot_confusion_matrix(Labels_val, RFC_pred_val, ["beam","reaction"])
print("Accuracy:", accuracy)
print("F1-score:", f1)
print("MCC:", mcc)
#print(RFC_pred_val)
# Out:
# {'bootstrap': True, 'max_features': 2, 'n_estimators': 6}
# RandomForestClassifier(max_features=2, n_estimators=6)
# [(0.4099821997383213, 'nrofpads'), (0.3554728324226841, 'charge'), (0.22249173811986514, 'z'), (0.00765927427193122, 'y'), (0.004393955447198183, 'x')]
# Confusion matrix for training set:
# Accuracy: 0.9975232198142415
# F1-score: 0.9975490196078431
# MCC: 0.9950581319705346
# [1 0 1 ... 1 0 1]
# Confusion matrix for validation set:
# Accuracy: 0.9944444444444445
# F1-score: 0.9942857142857142
# MCC: 0.9889417905532354

# %% [markdown]
# ### Dense Neural Network
# Now we try a dense neural network on these simple features

# %%
# Init the Sequential model
model = tf.keras.Sequential()
# Add Input layer
model.add(tf.keras.layers.InputLayer(input_shape=(5,)))
# Add hidden layer
model.add(tf.keras.layers.Dense(64, activation='tanh'))
model.add(tf.keras.layers.Dense(128, activation='tanh'))


# Add output layer.
model.add(tf.keras.layers.Dense(2, activation='softmax'))

# Finally, compile the model and print a summary. Loss function and optimizer is set during compilation.
model.compile(
    loss='binary_crossentropy',
    optimizer=keras.optimizers.Adam(learning_rate=0.001, beta_1=0.99, beta_2=0.999),
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                384
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 8,962
# Trainable params: 8,962
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Training DNN
# Now we train the neural network

# %%
# Set parameters for the training run. The full data set is only 2000x5 doubles so large nr of epochs and
# small batch_size will still work well even on cpu
epochs = 100
batch_size = 64

# %%
from keras.utils import to_categorical
Labels_train_onehot = to_categorical(Labels_train)
Labels_val_onehot = to_categorical(Labels_val)

# %% [markdown]
# Now the DNN is trained using the standard scaled data.

# %%
# The validation_data keywork expects a 'tuple' (val_x, val_y) so we make one on the fly
history = model.fit(
    xSimple_train_stsc,
    Labels_train_onehot,
    validation_data=(xSimple_val_stsc, Labels_val_onehot),
    epochs=epochs,
    batch_size=batch_size,
)
# Out:
# Epoch 1/100
# 26/26 [==============================] - 0s 5ms/step - loss: 0.2037 - accuracy: 0.9350 - val_loss: 0.0487 - val_accuracy: 0.9944
# Epoch 2/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0385 - accuracy: 0.9944 - val_loss: 0.0556 - val_accuracy: 0.9944
# Epoch 3/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0387 - accuracy: 0.9957 - val_loss: 0.0703 - val_accuracy: 0.9944
# Epoch 4/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.9957 - val_loss: 0.0784 - val_accuracy: 0.9944
# Epoch 5/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0423 - accuracy: 0.9950 - val_loss: 0.0824 - val_accuracy: 0.9944
# Epoch 6/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0421 - accuracy: 0.9950 - val_loss: 0.0840 - val_accuracy: 0.9944
# Epoch 7/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0421 - accuracy: 0.9950 - val_loss: 0.0845 - val_accuracy: 0.9944
# Epoch 8/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0414 - accuracy: 0.9950 - val_loss: 0.0849 - val_accuracy: 0.9944
# Epoch 9/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0404 - accuracy: 0.9944 - val_loss: 0.0838 - val_accuracy: 0.9944
# Epoch 10/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0390 - accuracy: 0.9950 - val_loss: 0.0822 - val_accuracy: 0.9944
# Epoch 11/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0375 - accuracy: 0.9950 - val_loss: 0.0797 - val_accuracy: 0.9944
# Epoch 12/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0368 - accuracy: 0.9957 - val_loss: 0.0768 - val_accuracy: 0.9944
# Epoch 13/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0360 - accuracy: 0.9957 - val_loss: 0.0737 - val_accuracy: 0.9944
# Epoch 14/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 0.9957 - val_loss: 0.0707 - val_accuracy: 0.9944
# Epoch 15/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 0.9957 - val_loss: 0.0685 - val_accuracy: 0.9944
# Epoch 16/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 0.9957 - val_loss: 0.0660 - val_accuracy: 0.9944
# Epoch 17/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0325 - accuracy: 0.9950 - val_loss: 0.0599 - val_accuracy: 0.9944
# Epoch 18/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0310 - accuracy: 0.9944 - val_loss: 0.0555 - val_accuracy: 0.9944
# Epoch 19/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0296 - accuracy: 0.9944 - val_loss: 0.0519 - val_accuracy: 0.9944
# Epoch 20/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0293 - accuracy: 0.9950 - val_loss: 0.0472 - val_accuracy: 0.9944
# Epoch 21/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0278 - accuracy: 0.9950 - val_loss: 0.0441 - val_accuracy: 0.9944
# Epoch 22/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0272 - accuracy: 0.9950 - val_loss: 0.0421 - val_accuracy: 0.9944
# Epoch 23/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0265 - accuracy: 0.9950 - val_loss: 0.0407 - val_accuracy: 0.9944
# Epoch 24/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0261 - accuracy: 0.9950 - val_loss: 0.0397 - val_accuracy: 0.9944
# Epoch 25/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0257 - accuracy: 0.9950 - val_loss: 0.0390 - val_accuracy: 0.9944
# Epoch 26/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0253 - accuracy: 0.9950 - val_loss: 0.0391 - val_accuracy: 0.9944
# Epoch 27/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0250 - accuracy: 0.9950 - val_loss: 0.0391 - val_accuracy: 0.9944
# Epoch 28/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0244 - accuracy: 0.9950 - val_loss: 0.0394 - val_accuracy: 0.9944
# Epoch 29/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 0.9950 - val_loss: 0.0394 - val_accuracy: 0.9944
# Epoch 30/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0235 - accuracy: 0.9950 - val_loss: 0.0399 - val_accuracy: 0.9944
# Epoch 31/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0234 - accuracy: 0.9950 - val_loss: 0.0401 - val_accuracy: 0.9944
# Epoch 32/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 0.9950 - val_loss: 0.0398 - val_accuracy: 0.9944
# Epoch 33/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0226 - accuracy: 0.9950 - val_loss: 0.0397 - val_accuracy: 0.9944
# Epoch 34/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0221 - accuracy: 0.9950 - val_loss: 0.0396 - val_accuracy: 0.9944
# Epoch 35/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0219 - accuracy: 0.9950 - val_loss: 0.0399 - val_accuracy: 0.9944
# Epoch 36/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0215 - accuracy: 0.9950 - val_loss: 0.0395 - val_accuracy: 0.9944
# Epoch 37/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0210 - accuracy: 0.9950 - val_loss: 0.0390 - val_accuracy: 0.9944
# Epoch 38/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0206 - accuracy: 0.9944 - val_loss: 0.0386 - val_accuracy: 0.9944
# Epoch 39/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 0.9944 - val_loss: 0.0382 - val_accuracy: 0.9944
# Epoch 40/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 0.9944 - val_loss: 0.0375 - val_accuracy: 0.9944
# Epoch 41/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 0.9944 - val_loss: 0.0373 - val_accuracy: 0.9944
# Epoch 42/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 0.9944 - val_loss: 0.0370 - val_accuracy: 0.9944
# Epoch 43/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 0.9944 - val_loss: 0.0369 - val_accuracy: 0.9944
# Epoch 44/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0190 - accuracy: 0.9944 - val_loss: 0.0368 - val_accuracy: 0.9944
# Epoch 45/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0188 - accuracy: 0.9944 - val_loss: 0.0373 - val_accuracy: 0.9944
# Epoch 46/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 0.9944 - val_loss: 0.0375 - val_accuracy: 0.9944
# Epoch 47/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.9944 - val_loss: 0.0377 - val_accuracy: 0.9944
# Epoch 48/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 0.9944 - val_loss: 0.0373 - val_accuracy: 0.9944
# Epoch 49/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9944 - val_loss: 0.0370 - val_accuracy: 0.9944
# Epoch 50/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0179 - accuracy: 0.9944 - val_loss: 0.0373 - val_accuracy: 0.9944
# Epoch 51/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 0.9944 - val_loss: 0.0371 - val_accuracy: 0.9944
# Epoch 52/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.9950 - val_loss: 0.0372 - val_accuracy: 0.9944
# Epoch 53/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0171 - accuracy: 0.9950 - val_loss: 0.0368 - val_accuracy: 0.9944
# Epoch 54/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.9950 - val_loss: 0.0374 - val_accuracy: 0.9944
# Epoch 55/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 0.9957 - val_loss: 0.0370 - val_accuracy: 0.9944
# Epoch 56/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 0.9957 - val_loss: 0.0367 - val_accuracy: 0.9944
# Epoch 57/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 0.9950 - val_loss: 0.0362 - val_accuracy: 0.9944
# Epoch 58/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0165 - accuracy: 0.9950 - val_loss: 0.0360 - val_accuracy: 0.9944
# Epoch 59/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.0358 - val_accuracy: 0.9944
# Epoch 60/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.0364 - val_accuracy: 0.9944
# Epoch 61/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.0363 - val_accuracy: 0.9944
# Epoch 62/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.9950 - val_loss: 0.0361 - val_accuracy: 0.9944
# Epoch 63/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.9950 - val_loss: 0.0356 - val_accuracy: 0.9944
# Epoch 64/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.9950 - val_loss: 0.0352 - val_accuracy: 0.9944
# Epoch 65/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0156 - accuracy: 0.9950 - val_loss: 0.0350 - val_accuracy: 0.9944
# Epoch 66/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0154 - accuracy: 0.9950 - val_loss: 0.0350 - val_accuracy: 0.9944
# Epoch 67/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 0.9950 - val_loss: 0.0352 - val_accuracy: 0.9944
# Epoch 68/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0152 - accuracy: 0.9950 - val_loss: 0.0345 - val_accuracy: 0.9944
# Epoch 69/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0151 - accuracy: 0.9950 - val_loss: 0.0342 - val_accuracy: 0.9944
# Epoch 70/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 0.9950 - val_loss: 0.0338 - val_accuracy: 0.9944
# Epoch 71/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.9950 - val_loss: 0.0337 - val_accuracy: 0.9944
# Epoch 72/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0148 - accuracy: 0.9957 - val_loss: 0.0337 - val_accuracy: 0.9944
# Epoch 73/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0146 - accuracy: 0.9957 - val_loss: 0.0336 - val_accuracy: 0.9944
# Epoch 74/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.9957 - val_loss: 0.0332 - val_accuracy: 0.9944
# Epoch 75/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 0.9957 - val_loss: 0.0328 - val_accuracy: 0.9944
# Epoch 76/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0145 - accuracy: 0.9957 - val_loss: 0.0328 - val_accuracy: 0.9944
# Epoch 77/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0142 - accuracy: 0.9957 - val_loss: 0.0324 - val_accuracy: 0.9944
# Epoch 78/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 0.9957 - val_loss: 0.0321 - val_accuracy: 0.9944
# Epoch 79/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0144 - accuracy: 0.9963 - val_loss: 0.0316 - val_accuracy: 0.9944
# Epoch 80/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0141 - accuracy: 0.9963 - val_loss: 0.0313 - val_accuracy: 0.9944
# Epoch 81/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0139 - accuracy: 0.9963 - val_loss: 0.0315 - val_accuracy: 0.9944
# Epoch 82/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0138 - accuracy: 0.9963 - val_loss: 0.0315 - val_accuracy: 0.9944
# Epoch 83/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 0.9963 - val_loss: 0.0311 - val_accuracy: 0.9944
# Epoch 84/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 0.9969 - val_loss: 0.0306 - val_accuracy: 0.9944
# Epoch 85/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 0.9969 - val_loss: 0.0305 - val_accuracy: 0.9944
# Epoch 86/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 0.9969 - val_loss: 0.0307 - val_accuracy: 0.9944
# Epoch 87/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 0.9969 - val_loss: 0.0304 - val_accuracy: 0.9944
# Epoch 88/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 0.9969 - val_loss: 0.0302 - val_accuracy: 0.9944
# Epoch 89/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 0.9969 - val_loss: 0.0301 - val_accuracy: 0.9944
# Epoch 90/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0132 - accuracy: 0.9969 - val_loss: 0.0302 - val_accuracy: 0.9944
# Epoch 91/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 0.9969 - val_loss: 0.0303 - val_accuracy: 0.9944
# Epoch 92/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 0.9969 - val_loss: 0.0305 - val_accuracy: 0.9944
# Epoch 93/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0128 - accuracy: 0.9969 - val_loss: 0.0298 - val_accuracy: 0.9944
# Epoch 94/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0128 - accuracy: 0.9969 - val_loss: 0.0299 - val_accuracy: 0.9944
# Epoch 95/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0125 - accuracy: 0.9969 - val_loss: 0.0288 - val_accuracy: 0.9944
# Epoch 96/100
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0128 - accuracy: 0.9969 - val_loss: 0.0277 - val_accuracy: 0.9944
# Epoch 97/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 0.9969 - val_loss: 0.0272 - val_accuracy: 0.9944
# Epoch 98/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0125 - accuracy: 0.9969 - val_loss: 0.0270 - val_accuracy: 0.9944
# Epoch 99/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 0.9969 - val_loss: 0.0274 - val_accuracy: 0.9944
# Epoch 100/100
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0125 - accuracy: 0.9969 - val_loss: 0.0274 - val_accuracy: 0.9944

# %% [markdown]
# #### Visualisation of results

# %%
# Plot loss and val_loss as one plot, and accuracy and val_accuracy as another, side-by-side.
# We'll also save this plot as plot_history() in the helper_functions file, so any time we need to
# plot the history object like this we can just call that function and pass the history object as
# an argument.
fig, ax = plt.subplots(1, 2, figsize=(14, 6))
num_epochs = len(history.history['loss'])
ax[0].plot(history.history['loss'], label='training')
ax[0].plot(history.history['val_loss'], label='validation')
#ax[0].plot(history2.history['loss'], label='training my method')
#ax[0].plot(history2.history['val_loss'], label='validation my method')
ax[0].set_title("Model loss")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("Loss")
ax[0].set_xticks(np.arange(num_epochs))
ax[0].legend()

ax[1].plot(history.history['accuracy'], label='training')
ax[1].plot(history.history['val_accuracy'], label='validation')
#ax[1].plot(history2.history['accuracy'], label='training my method')
#ax[1].plot(history2.history['val_accuracy'], label='validation my method')
ax[1].set_title("Model accuracy")
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Accuracy")
ax[1].set_xticks(np.arange(num_epochs))
ax[1].legend()

#the _pre contain a number in [0,1] these get mapped to 1 if >0.5 and to 0 if <0.5
DNN_pred_train_pre = model.predict(xSimple_train_stsc)
DNN_pred_val_pre = model.predict(xSimple_val_stsc)

DNN_pred_train_pre = np.array([ np.argmax(i) for i in  DNN_pred_train_pre])
DNN_pred_val_pre = np.array([ np.argmax(i) for i in  DNN_pred_val_pre])


accuracy_train = accuracy_score(Labels_train, DNN_pred_train_pre)
confmat_train = confusion_matrix(Labels_train, DNN_pred_train_pre)
f1_train = f1_score(Labels_train, DNN_pred_train_pre)
mcc_train = matthews_corrcoef(Labels_train, DNN_pred_train_pre)

accuracy = accuracy_score(Labels_val, DNN_pred_val_pre)
confmat = confusion_matrix(Labels_val, DNN_pred_val_pre)
f1 = f1_score(Labels_val, DNN_pred_val_pre)
mcc = matthews_corrcoef(Labels_val, DNN_pred_val_pre)

print("Confusion matrix for training set:\n")
plot_confusion_matrix(Labels_train, DNN_pred_train_pre, ["beam","reaction"])
print("Accuracy:", accuracy_train)
print("F1-score:", f1_train)
print("MCC:", mcc_train)
print(RFC_pred_train)

print("Confusion matrix for validation set:\n")
plot_confusion_matrix(Labels_val, DNN_pred_val_pre, ["beam","reaction"])
print("Accuracy:", accuracy)
print("F1-score:", f1)
print("MCC:", mcc)
# Out:
# Confusion matrix for training set:
# Accuracy: 0.9969040247678018
# F1-score: 0.996934396076027
# MCC: 0.9938265564282749
# [1 0 1 ... 1 0 1]
# Confusion matrix for validation set:
# Accuracy: 0.9944444444444445
# F1-score: 0.9942857142857142
# MCC: 0.9889417905532354

# %% [markdown]
# ### K-Means
# Here we try k-means to separate beam from reaction events

# %%
from sklearn.cluster import KMeans
clust = KMeans(n_clusters=2).fit(xSimple_train_stsc)
print(clust.labels_)
KM_pred_train = clust.predict(xSimple_train_stsc)
KM_pred_val = clust.predict(xSimple_val_stsc)

#Now we need to find out which cluster is which type of event
#We select the one that gives best accuracy on training set

accuracy_train_norm = accuracy_score(Labels_train, KM_pred_train)
accuracy_train_swap = accuracy_score(Labels_train, 1-KM_pred_train)

if(accuracy_train_swap>accuracy_train_norm):
    KM_pred_train = 1- KM_pred_train
    KM_pred_val = 1 - KM_pred_val

accuracy_train = accuracy_score(Labels_train, KM_pred_train)
confmat_train = confusion_matrix(Labels_train, KM_pred_train)
f1_train = f1_score(Labels_train, KM_pred_train)
mcc_train = matthews_corrcoef(Labels_train, KM_pred_train)

accuracy = accuracy_score(Labels_val, KM_pred_val)
confmat = confusion_matrix(Labels_val, KM_pred_val)
f1 = f1_score(Labels_val, KM_pred_val)
mcc = matthews_corrcoef(Labels_val, KM_pred_val)

print("Confusion matrix for training set:\n")
plot_confusion_matrix(Labels_train, KM_pred_train, ["beam","reaction"])
print("Accuracy:", accuracy_train)
print("F1-score:", f1_train)
print("MCC:", mcc_train)

print("Confusion matrix for validation set:\n")
plot_confusion_matrix(Labels_val, KM_pred_val, ["beam","reaction"])
print("Accuracy:", accuracy)
print("F1-score:", f1)
print("MCC:", mcc)
# Out:
# [0 1 0 ... 0 1 0]
# Confusion matrix for training set:
# Accuracy: 0.8848297213622291
# F1-score: 0.8974641675854466
# MCC: 0.7884727572436118
# Confusion matrix for validation set:
# Accuracy: 0.8833333333333333
# F1-score: 0.8923076923076922
# MCC: 0.7851892150744064

# %% [markdown]
# #### Elbow method for K-Means
# Here we look for the optimal number of clusters for kmeans. Even with more clusters than our (2) available classes
# we can still assign them each to 1 or 0 based on which mapping gives the best results.
#
# Based on [Geron notebook](https://github.com/ageron/handson-ml/blob/master/08_dimensionality_reduction.ipynb)
#         (search for 'finding the optimal number of clusters')

# %%
k_rng = range(1,10)
sse = []

for k in k_rng:
    km = KMeans(n_clusters=k)
    km.fit(xSimple_train_stsc)
    sse.append(km.inertia_)

sse
plt.xlabel('K')
plt.ylabel('SSE') #sum of squared error

plt.plot(k_rng,sse)

# %% [markdown]
# Based on shoulder method we can use 3 or 5 clusters as well.
# Let us try both cases.
# First 3 clusters case.
# #### 3-Cluster K-Means

# %%
nclusters = 3
clust3 = KMeans(n_clusters=nclusters).fit(xSimple_train_stsc)
print(clust3.labels_)
KM3_pred_train = clust3.predict(xSimple_train_stsc)
KM3_pred_val = clust3.predict(xSimple_val_stsc)

#Now we need to find out which cluster is which type of event
#We select the one that gives best accuracy on training set
#for this we loop over all combinations without trivial ones (all beam or all reaction)
#we denote accuracy_train_010 if cluster 0->0, 1->1 and 2->0

KM3_pred_train_001 = np.zeros(len(KM3_pred_train))
KM3_pred_train_010 = np.zeros(len(KM3_pred_train))
KM3_pred_train_011 = np.zeros(len(KM3_pred_train))
KM3_pred_train_100 = np.zeros(len(KM3_pred_train))
KM3_pred_train_101 = np.zeros(len(KM3_pred_train))
KM3_pred_train_110 = np.zeros(len(KM3_pred_train))
KM3_pred_val_001 = np.zeros(len(KM3_pred_val))
KM3_pred_val_010 = np.zeros(len(KM3_pred_val))
KM3_pred_val_011 = np.zeros(len(KM3_pred_val))
KM3_pred_val_100 = np.zeros(len(KM3_pred_val))
KM3_pred_val_101 = np.zeros(len(KM3_pred_val))
KM3_pred_val_110 = np.zeros(len(KM3_pred_val))

for i in range(len(KM3_pred_train)):
    if (KM3_pred_train[i]==0):
        KM3_pred_train_001[i] = 0
        KM3_pred_train_010[i] = 0
        KM3_pred_train_011[i] = 0
        KM3_pred_train_100[i] = 1
        KM3_pred_train_101[i] = 1
        KM3_pred_train_110[i] = 1
    if (KM3_pred_train[i]==1):
        KM3_pred_train_001[i] = 0
        KM3_pred_train_010[i] = 1
        KM3_pred_train_011[i] = 1
        KM3_pred_train_100[i] = 0
        KM3_pred_train_101[i] = 0
        KM3_pred_train_110[i] = 1
    if (KM3_pred_train[i]==2):
        KM3_pred_train_001[i] = 1
        KM3_pred_train_010[i] = 0
        KM3_pred_train_011[i] = 1
        KM3_pred_train_100[i] = 0
        KM3_pred_train_101[i] = 1
        KM3_pred_train_110[i] = 0
        
for i in range(len(KM3_pred_val)):
    if (KM3_pred_val[i]==0):
        KM3_pred_val_001[i] = 0
        KM3_pred_val_010[i] = 0
        KM3_pred_val_011[i] = 0
        KM3_pred_val_100[i] = 1
        KM3_pred_val_101[i] = 1
        KM3_pred_val_110[i] = 1
    if (KM3_pred_val[i]==1):
        KM3_pred_val_001[i] = 0
        KM3_pred_val_010[i] = 1
        KM3_pred_val_011[i] = 1
        KM3_pred_val_100[i] = 0
        KM3_pred_val_101[i] = 0
        KM3_pred_val_110[i] = 1
    if (KM3_pred_val[i]==2):
        KM3_pred_val_001[i] = 1
        KM3_pred_val_010[i] = 0
        KM3_pred_val_011[i] = 1
        KM3_pred_val_100[i] = 0
        KM3_pred_val_101[i] = 1
        KM3_pred_val_110[i] = 0

        
        

accuracy_train_001 = accuracy_score(Labels_train, KM3_pred_train_001)
accuracy_train_010 = accuracy_score(Labels_train, KM3_pred_train_010)
accuracy_train_011 = accuracy_score(Labels_train, KM3_pred_train_011)
accuracy_train_100 = accuracy_score(Labels_train, KM3_pred_train_100)
accuracy_train_101 = accuracy_score(Labels_train, KM3_pred_train_101)
accuracy_train_110 = accuracy_score(Labels_train, KM3_pred_train_110)

KM3_tr_acc_list = [accuracy_train_001, accuracy_train_010, accuracy_train_011, accuracy_train_100, 
                   accuracy_train_101, accuracy_train_110]
print(KM3_tr_acc_list)

#Finds best accuracy model
max_accuracy_KM3_train = max(KM3_tr_acc_list)
max_index_KM3 = KM3_tr_acc_list.index(max_accuracy_KM3_train)

if (max_index_KM3==0):
    KM3_pred_train = KM3_pred_train_001
    KM3_pred_val = KM3_pred_val_001
elif (max_index_KM3==1):
    KM3_pred_train = KM3_pred_train_010
    KM3_pred_val = KM3_pred_val_010
elif (max_index_KM3==2):
    KM3_pred_train = KM3_pred_train_011
    KM3_pred_val = KM3_pred_val_011
elif (max_index_KM3==3):
    KM3_pred_train = KM3_pred_train_100
    KM3_pred_val = KM3_pred_val_100
elif (max_index_KM3==4):
    KM3_pred_train = KM3_pred_train_101
    KM3_pred_val = KM3_pred_val_101
elif (max_index_KM3==5):
    KM3_pred_train = KM3_pred_train_110
    KM3_pred_val = KM3_pred_val_110
    

accuracy_train = accuracy_score(Labels_train, KM3_pred_train)
confmat_train = confusion_matrix(Labels_train, KM3_pred_train)
f1_train = f1_score(Labels_train, KM3_pred_train)
mcc_train = matthews_corrcoef(Labels_train, KM3_pred_train)

accuracy = accuracy_score(Labels_val, KM3_pred_val)
confmat = confusion_matrix(Labels_val, KM3_pred_val)
f1 = f1_score(Labels_val, KM3_pred_val)
mcc = matthews_corrcoef(Labels_val, KM3_pred_val)

print("Confusion matrix for training set:\n")
plot_confusion_matrix(Labels_train, KM3_pred_train, ["beam","reaction"])
print("Accuracy:", accuracy_train)
print("F1-score:", f1_train)
print("MCC:", mcc_train)

print("Confusion matrix for validation set:\n")
plot_confusion_matrix(Labels_val, KM3_pred_val, ["beam","reaction"])
print("Accuracy:", accuracy)
print("F1-score:", f1)
print("MCC:", mcc)
# Out:
# [1 0 1 ... 1 0 1]
# [0.3021671826625387, 0.8755417956656347, 0.6842105263157895, 0.3157894736842105, 0.12445820433436533, 0.6978328173374613]
# Confusion matrix for training set:
# Accuracy: 0.8755417956656347
# F1-score: 0.890103881902679
# MCC: 0.7728131891288388
# Confusion matrix for validation set:
# Accuracy: 0.8611111111111112
# F1-score: 0.8743718592964823
# MCC: 0.7482409171332517

# %% [markdown]
# #### 3-Cluster K-Means
# and now for 5 clusters

# %%
nclusters = 5
clust5 = KMeans(n_clusters=nclusters).fit(xSimple_train_stsc)
print(clust5.labels_)
KM5_pred_train = clust5.predict(xSimple_train_stsc)
KM5_pred_val = clust5.predict(xSimple_val_stsc)

#Now we need to find out which cluster is which type of event
#We select the one that gives best accuracy on training set
#for this we loop over all combinations without trivial ones (all beam or all reaction)
#we denote accuracy_train_01010 if cluster 0->0, 1->1, 2->0, 3->1 and 4->1

KM5_pred_train_00001 = np.zeros(len(KM5_pred_train))
KM5_pred_train_00010 = np.zeros(len(KM5_pred_train))
KM5_pred_train_00011 = np.zeros(len(KM5_pred_train))
KM5_pred_train_00100 = np.zeros(len(KM5_pred_train))
KM5_pred_train_00101 = np.zeros(len(KM5_pred_train))
KM5_pred_train_00110 = np.zeros(len(KM5_pred_train))
KM5_pred_train_00111 = np.zeros(len(KM5_pred_train))
KM5_pred_train_01000 = np.zeros(len(KM5_pred_train))
KM5_pred_train_01001 = np.zeros(len(KM5_pred_train))
KM5_pred_train_01010 = np.zeros(len(KM5_pred_train))
KM5_pred_train_01011 = np.zeros(len(KM5_pred_train))
KM5_pred_train_01100 = np.zeros(len(KM5_pred_train))
KM5_pred_train_01101 = np.zeros(len(KM5_pred_train))
KM5_pred_train_01110 = np.zeros(len(KM5_pred_train))
KM5_pred_train_01111 = np.zeros(len(KM5_pred_train))
KM5_pred_train_10000 = np.zeros(len(KM5_pred_train))
KM5_pred_train_10001 = np.zeros(len(KM5_pred_train))
KM5_pred_train_10010 = np.zeros(len(KM5_pred_train))
KM5_pred_train_10011 = np.zeros(len(KM5_pred_train))
KM5_pred_train_10100 = np.zeros(len(KM5_pred_train))
KM5_pred_train_10101 = np.zeros(len(KM5_pred_train))
KM5_pred_train_10110 = np.zeros(len(KM5_pred_train))
KM5_pred_train_10111 = np.zeros(len(KM5_pred_train))
KM5_pred_train_11000 = np.zeros(len(KM5_pred_train))
KM5_pred_train_11001 = np.zeros(len(KM5_pred_train))
KM5_pred_train_11010 = np.zeros(len(KM5_pred_train))
KM5_pred_train_11011 = np.zeros(len(KM5_pred_train))
KM5_pred_train_11100 = np.zeros(len(KM5_pred_train))
KM5_pred_train_11101 = np.zeros(len(KM5_pred_train))
KM5_pred_train_11110 = np.zeros(len(KM5_pred_train))

KM5_pred_val_00001 = np.zeros(len(KM5_pred_val))
KM5_pred_val_00010 = np.zeros(len(KM5_pred_val))
KM5_pred_val_00011 = np.zeros(len(KM5_pred_val))
KM5_pred_val_00100 = np.zeros(len(KM5_pred_val))
KM5_pred_val_00101 = np.zeros(len(KM5_pred_val))
KM5_pred_val_00110 = np.zeros(len(KM5_pred_val))
KM5_pred_val_00111 = np.zeros(len(KM5_pred_val))
KM5_pred_val_01000 = np.zeros(len(KM5_pred_val))
KM5_pred_val_01001 = np.zeros(len(KM5_pred_val))
KM5_pred_val_01010 = np.zeros(len(KM5_pred_val))
KM5_pred_val_01011 = np.zeros(len(KM5_pred_val))
KM5_pred_val_01100 = np.zeros(len(KM5_pred_val))
KM5_pred_val_01101 = np.zeros(len(KM5_pred_val))
KM5_pred_val_01110 = np.zeros(len(KM5_pred_val))
KM5_pred_val_01111 = np.zeros(len(KM5_pred_val))
KM5_pred_val_10000 = np.zeros(len(KM5_pred_val))
KM5_pred_val_10001 = np.zeros(len(KM5_pred_val))
KM5_pred_val_10010 = np.zeros(len(KM5_pred_val))
KM5_pred_val_10011 = np.zeros(len(KM5_pred_val))
KM5_pred_val_10100 = np.zeros(len(KM5_pred_val))
KM5_pred_val_10101 = np.zeros(len(KM5_pred_val))
KM5_pred_val_10110 = np.zeros(len(KM5_pred_val))
KM5_pred_val_10111 = np.zeros(len(KM5_pred_val))
KM5_pred_val_11000 = np.zeros(len(KM5_pred_val))
KM5_pred_val_11001 = np.zeros(len(KM5_pred_val))
KM5_pred_val_11010 = np.zeros(len(KM5_pred_val))
KM5_pred_val_11011 = np.zeros(len(KM5_pred_val))
KM5_pred_val_11100 = np.zeros(len(KM5_pred_val))
KM5_pred_val_11101 = np.zeros(len(KM5_pred_val))
KM5_pred_val_11110 = np.zeros(len(KM5_pred_val))

for i in range(len(KM5_pred_train)):
    if (KM5_pred_train[i]==0):
        KM5_pred_train_00001[i] = 0
        KM5_pred_train_00010[i] = 0
        KM5_pred_train_00011[i] = 0
        KM5_pred_train_00100[i] = 0
        KM5_pred_train_00101[i] = 0
        KM5_pred_train_00110[i] = 0
        KM5_pred_train_00111[i] = 0
        KM5_pred_train_01000[i] = 0
        KM5_pred_train_01001[i] = 0
        KM5_pred_train_01010[i] = 0
        KM5_pred_train_01011[i] = 0
        KM5_pred_train_01100[i] = 0
        KM5_pred_train_01101[i] = 0
        KM5_pred_train_01110[i] = 0
        KM5_pred_train_01111[i] = 0
        KM5_pred_train_10000[i] = 1
        KM5_pred_train_10001[i] = 1
        KM5_pred_train_10010[i] = 1
        KM5_pred_train_10011[i] = 1
        KM5_pred_train_10100[i] = 1
        KM5_pred_train_10101[i] = 1
        KM5_pred_train_10110[i] = 1
        KM5_pred_train_10111[i] = 1
        KM5_pred_train_11000[i] = 1
        KM5_pred_train_11001[i] = 1
        KM5_pred_train_11010[i] = 1
        KM5_pred_train_11011[i] = 1
        KM5_pred_train_11100[i] = 1
        KM5_pred_train_11101[i] = 1
        KM5_pred_train_11110[i] = 1
    if (KM5_pred_train[i]==1):
        KM5_pred_train_00001[i] = 0
        KM5_pred_train_00010[i] = 0
        KM5_pred_train_00011[i] = 0
        KM5_pred_train_00100[i] = 0
        KM5_pred_train_00101[i] = 0
        KM5_pred_train_00110[i] = 0
        KM5_pred_train_00111[i] = 0
        KM5_pred_train_01000[i] = 1
        KM5_pred_train_01001[i] = 1
        KM5_pred_train_01010[i] = 1
        KM5_pred_train_01011[i] = 1
        KM5_pred_train_01100[i] = 1
        KM5_pred_train_01101[i] = 1
        KM5_pred_train_01110[i] = 1
        KM5_pred_train_01111[i] = 1
        KM5_pred_train_10000[i] = 0
        KM5_pred_train_10001[i] = 0
        KM5_pred_train_10010[i] = 0
        KM5_pred_train_10011[i] = 0
        KM5_pred_train_10100[i] = 0
        KM5_pred_train_10101[i] = 0
        KM5_pred_train_10110[i] = 0
        KM5_pred_train_10111[i] = 0
        KM5_pred_train_11000[i] = 1
        KM5_pred_train_11001[i] = 1
        KM5_pred_train_11010[i] = 1
        KM5_pred_train_11011[i] = 1
        KM5_pred_train_11100[i] = 1
        KM5_pred_train_11101[i] = 1
        KM5_pred_train_11110[i] = 1
    if (KM5_pred_train[i]==2):
        KM5_pred_train_00001[i] = 0
        KM5_pred_train_00010[i] = 0
        KM5_pred_train_00011[i] = 0
        KM5_pred_train_00100[i] = 1
        KM5_pred_train_00101[i] = 1
        KM5_pred_train_00110[i] = 1
        KM5_pred_train_00111[i] = 1
        KM5_pred_train_01000[i] = 0
        KM5_pred_train_01001[i] = 0
        KM5_pred_train_01010[i] = 0
        KM5_pred_train_01011[i] = 0
        KM5_pred_train_01100[i] = 1
        KM5_pred_train_01101[i] = 1
        KM5_pred_train_01110[i] = 1
        KM5_pred_train_01111[i] = 1
        KM5_pred_train_10000[i] = 0
        KM5_pred_train_10001[i] = 0
        KM5_pred_train_10010[i] = 0
        KM5_pred_train_10011[i] = 0
        KM5_pred_train_10100[i] = 1
        KM5_pred_train_10101[i] = 1
        KM5_pred_train_10110[i] = 1
        KM5_pred_train_10111[i] = 1
        KM5_pred_train_11000[i] = 0
        KM5_pred_train_11001[i] = 0
        KM5_pred_train_11010[i] = 0
        KM5_pred_train_11011[i] = 0
        KM5_pred_train_11100[i] = 1
        KM5_pred_train_11101[i] = 1
        KM5_pred_train_11110[i] = 1
    if (KM5_pred_train[i]==3):
        KM5_pred_train_00001[i] = 0
        KM5_pred_train_00010[i] = 1
        KM5_pred_train_00011[i] = 1
        KM5_pred_train_00100[i] = 0
        KM5_pred_train_00101[i] = 0
        KM5_pred_train_00110[i] = 1
        KM5_pred_train_00111[i] = 1
        KM5_pred_train_01000[i] = 0
        KM5_pred_train_01001[i] = 0
        KM5_pred_train_01010[i] = 1
        KM5_pred_train_01011[i] = 1
        KM5_pred_train_01100[i] = 0
        KM5_pred_train_01101[i] = 0
        KM5_pred_train_01110[i] = 1
        KM5_pred_train_01111[i] = 1
        KM5_pred_train_10000[i] = 0
        KM5_pred_train_10001[i] = 0
        KM5_pred_train_10010[i] = 1
        KM5_pred_train_10011[i] = 1
        KM5_pred_train_10100[i] = 0
        KM5_pred_train_10101[i] = 0
        KM5_pred_train_10110[i] = 1
        KM5_pred_train_10111[i] = 1
        KM5_pred_train_11000[i] = 0
        KM5_pred_train_11001[i] = 0
        KM5_pred_train_11010[i] = 1
        KM5_pred_train_11011[i] = 1
        KM5_pred_train_11100[i] = 0
        KM5_pred_train_11101[i] = 0
        KM5_pred_train_11110[i] = 1
    if (KM5_pred_train[i]==4):
        KM5_pred_train_00001[i] = 1
        KM5_pred_train_00010[i] = 0
        KM5_pred_train_00011[i] = 1
        KM5_pred_train_00100[i] = 0
        KM5_pred_train_00101[i] = 1
        KM5_pred_train_00110[i] = 0
        KM5_pred_train_00111[i] = 1
        KM5_pred_train_01000[i] = 0
        KM5_pred_train_01001[i] = 1
        KM5_pred_train_01010[i] = 0
        KM5_pred_train_01011[i] = 1
        KM5_pred_train_01100[i] = 0
        KM5_pred_train_01101[i] = 1
        KM5_pred_train_01110[i] = 0
        KM5_pred_train_01111[i] = 1
        KM5_pred_train_10000[i] = 0
        KM5_pred_train_10001[i] = 1
        KM5_pred_train_10010[i] = 0
        KM5_pred_train_10011[i] = 1
        KM5_pred_train_10100[i] = 0
        KM5_pred_train_10101[i] = 1
        KM5_pred_train_10110[i] = 0
        KM5_pred_train_10111[i] = 1
        KM5_pred_train_11000[i] = 0
        KM5_pred_train_11001[i] = 1
        KM5_pred_train_11010[i] = 0
        KM5_pred_train_11011[i] = 1
        KM5_pred_train_11100[i] = 0
        KM5_pred_train_11101[i] = 1
        KM5_pred_train_11110[i] = 0
        
for i in range(len(KM5_pred_val)):
    if (KM5_pred_val[i]==0):
        KM5_pred_val_00001[i] = 0
        KM5_pred_val_00010[i] = 0
        KM5_pred_val_00011[i] = 0
        KM5_pred_val_00100[i] = 0
        KM5_pred_val_00101[i] = 0
        KM5_pred_val_00110[i] = 0
        KM5_pred_val_00111[i] = 0
        KM5_pred_val_01000[i] = 0
        KM5_pred_val_01001[i] = 0
        KM5_pred_val_01010[i] = 0
        KM5_pred_val_01011[i] = 0
        KM5_pred_val_01100[i] = 0
        KM5_pred_val_01101[i] = 0
        KM5_pred_val_01110[i] = 0
        KM5_pred_val_01111[i] = 0
        KM5_pred_val_10000[i] = 1
        KM5_pred_val_10001[i] = 1
        KM5_pred_val_10010[i] = 1
        KM5_pred_val_10011[i] = 1
        KM5_pred_val_10100[i] = 1
        KM5_pred_val_10101[i] = 1
        KM5_pred_val_10110[i] = 1
        KM5_pred_val_10111[i] = 1
        KM5_pred_val_11000[i] = 1
        KM5_pred_val_11001[i] = 1
        KM5_pred_val_11010[i] = 1
        KM5_pred_val_11011[i] = 1
        KM5_pred_val_11100[i] = 1
        KM5_pred_val_11101[i] = 1
        KM5_pred_val_11110[i] = 1
    if (KM5_pred_train[i]==1):
        KM5_pred_val_00001[i] = 0
        KM5_pred_val_00010[i] = 0
        KM5_pred_val_00011[i] = 0
        KM5_pred_val_00100[i] = 0
        KM5_pred_val_00101[i] = 0
        KM5_pred_val_00110[i] = 0
        KM5_pred_val_00111[i] = 0
        KM5_pred_val_01000[i] = 1
        KM5_pred_val_01001[i] = 1
        KM5_pred_val_01010[i] = 1
        KM5_pred_val_01011[i] = 1
        KM5_pred_val_01100[i] = 1
        KM5_pred_val_01101[i] = 1
        KM5_pred_val_01110[i] = 1
        KM5_pred_val_01111[i] = 1
        KM5_pred_val_10000[i] = 0
        KM5_pred_val_10001[i] = 0
        KM5_pred_val_10010[i] = 0
        KM5_pred_val_10011[i] = 0
        KM5_pred_val_10100[i] = 0
        KM5_pred_val_10101[i] = 0
        KM5_pred_val_10110[i] = 0
        KM5_pred_val_10111[i] = 0
        KM5_pred_val_11000[i] = 1
        KM5_pred_val_11001[i] = 1
        KM5_pred_val_11010[i] = 1
        KM5_pred_val_11011[i] = 1
        KM5_pred_val_11100[i] = 1
        KM5_pred_val_11101[i] = 1
        KM5_pred_val_11110[i] = 1
    if (KM5_pred_train[i]==2):
        KM5_pred_val_00001[i] = 0
        KM5_pred_val_00010[i] = 0
        KM5_pred_val_00011[i] = 0
        KM5_pred_val_00100[i] = 1
        KM5_pred_val_00101[i] = 1
        KM5_pred_val_00110[i] = 1
        KM5_pred_val_00111[i] = 1
        KM5_pred_val_01000[i] = 0
        KM5_pred_val_01001[i] = 0
        KM5_pred_val_01010[i] = 0
        KM5_pred_val_01011[i] = 0
        KM5_pred_val_01100[i] = 1
        KM5_pred_val_01101[i] = 1
        KM5_pred_val_01110[i] = 1
        KM5_pred_val_01111[i] = 1
        KM5_pred_val_10000[i] = 0
        KM5_pred_val_10001[i] = 0
        KM5_pred_val_10010[i] = 0
        KM5_pred_val_10011[i] = 0
        KM5_pred_val_10100[i] = 1
        KM5_pred_val_10101[i] = 1
        KM5_pred_val_10110[i] = 1
        KM5_pred_val_10111[i] = 1
        KM5_pred_val_11000[i] = 0
        KM5_pred_val_11001[i] = 0
        KM5_pred_val_11010[i] = 0
        KM5_pred_val_11011[i] = 0
        KM5_pred_val_11100[i] = 1
        KM5_pred_val_11101[i] = 1
        KM5_pred_val_11110[i] = 1
    if (KM5_pred_train[i]==3):
        KM5_pred_val_00001[i] = 0
        KM5_pred_val_00010[i] = 1
        KM5_pred_val_00011[i] = 1
        KM5_pred_val_00100[i] = 0
        KM5_pred_val_00101[i] = 0
        KM5_pred_val_00110[i] = 1
        KM5_pred_val_00111[i] = 1
        KM5_pred_val_01000[i] = 0
        KM5_pred_val_01001[i] = 0
        KM5_pred_val_01010[i] = 1
        KM5_pred_val_01011[i] = 1
        KM5_pred_val_01100[i] = 0
        KM5_pred_val_01101[i] = 0
        KM5_pred_val_01110[i] = 1
        KM5_pred_val_01111[i] = 1
        KM5_pred_val_10000[i] = 0
        KM5_pred_val_10001[i] = 0
        KM5_pred_val_10010[i] = 1
        KM5_pred_val_10011[i] = 1
        KM5_pred_val_10100[i] = 0
        KM5_pred_val_10101[i] = 0
        KM5_pred_val_10110[i] = 1
        KM5_pred_val_10111[i] = 1
        KM5_pred_val_11000[i] = 0
        KM5_pred_val_11001[i] = 0
        KM5_pred_val_11010[i] = 1
        KM5_pred_val_11011[i] = 1
        KM5_pred_val_11100[i] = 0
        KM5_pred_val_11101[i] = 0
        KM5_pred_val_11110[i] = 1
    if (KM5_pred_train[i]==4):
        KM5_pred_val_00001[i] = 1
        KM5_pred_val_00010[i] = 0
        KM5_pred_val_00011[i] = 1
        KM5_pred_val_00100[i] = 0
        KM5_pred_val_00101[i] = 1
        KM5_pred_val_00110[i] = 0
        KM5_pred_val_00111[i] = 1
        KM5_pred_val_01000[i] = 0
        KM5_pred_val_01001[i] = 1
        KM5_pred_val_01010[i] = 0
        KM5_pred_val_01011[i] = 1
        KM5_pred_val_01100[i] = 0
        KM5_pred_val_01101[i] = 1
        KM5_pred_val_01110[i] = 0
        KM5_pred_val_01111[i] = 1
        KM5_pred_val_10000[i] = 0
        KM5_pred_val_10001[i] = 1
        KM5_pred_val_10010[i] = 0
        KM5_pred_val_10011[i] = 1
        KM5_pred_val_10100[i] = 0
        KM5_pred_val_10101[i] = 1
        KM5_pred_val_10110[i] = 0
        KM5_pred_val_10111[i] = 1
        KM5_pred_val_11000[i] = 0
        KM5_pred_val_11001[i] = 1
        KM5_pred_val_11010[i] = 0
        KM5_pred_val_11011[i] = 1
        KM5_pred_val_11100[i] = 0
        KM5_pred_val_11101[i] = 1
        KM5_pred_val_11110[i] = 0
        

        
        

accuracy_train_00001 = accuracy_score(Labels_train, KM5_pred_train_00001)
accuracy_train_00010 = accuracy_score(Labels_train, KM5_pred_train_00010)
accuracy_train_00011 = accuracy_score(Labels_train, KM5_pred_train_00011)
accuracy_train_00100 = accuracy_score(Labels_train, KM5_pred_train_00100)
accuracy_train_00101 = accuracy_score(Labels_train, KM5_pred_train_00101)
accuracy_train_00110 = accuracy_score(Labels_train, KM5_pred_train_00110)
accuracy_train_00111 = accuracy_score(Labels_train, KM5_pred_train_00111)
accuracy_train_01000 = accuracy_score(Labels_train, KM5_pred_train_01000)
accuracy_train_01001 = accuracy_score(Labels_train, KM5_pred_train_01001)
accuracy_train_01010 = accuracy_score(Labels_train, KM5_pred_train_01010)
accuracy_train_01011 = accuracy_score(Labels_train, KM5_pred_train_01011)
accuracy_train_01100 = accuracy_score(Labels_train, KM5_pred_train_01100)
accuracy_train_01101 = accuracy_score(Labels_train, KM5_pred_train_01101)
accuracy_train_01110 = accuracy_score(Labels_train, KM5_pred_train_01110)
accuracy_train_01111 = accuracy_score(Labels_train, KM5_pred_train_01111)
accuracy_train_10000 = accuracy_score(Labels_train, KM5_pred_train_10000)
accuracy_train_10001 = accuracy_score(Labels_train, KM5_pred_train_10001)
accuracy_train_10010 = accuracy_score(Labels_train, KM5_pred_train_10010)
accuracy_train_10011 = accuracy_score(Labels_train, KM5_pred_train_10011)
accuracy_train_10100 = accuracy_score(Labels_train, KM5_pred_train_10100)
accuracy_train_10101 = accuracy_score(Labels_train, KM5_pred_train_10101)
accuracy_train_10110 = accuracy_score(Labels_train, KM5_pred_train_10110)
accuracy_train_10111 = accuracy_score(Labels_train, KM5_pred_train_10111)
accuracy_train_11000 = accuracy_score(Labels_train, KM5_pred_train_11000)
accuracy_train_11001 = accuracy_score(Labels_train, KM5_pred_train_11001)
accuracy_train_11010 = accuracy_score(Labels_train, KM5_pred_train_11010)
accuracy_train_11011 = accuracy_score(Labels_train, KM5_pred_train_11011)
accuracy_train_11100 = accuracy_score(Labels_train, KM5_pred_train_11100)
accuracy_train_11101 = accuracy_score(Labels_train, KM5_pred_train_11101)
accuracy_train_11110 = accuracy_score(Labels_train, KM5_pred_train_11110)

f1_train_00001 = f1_score(Labels_train, KM5_pred_train_00001)
f1_train_00010 = f1_score(Labels_train, KM5_pred_train_00010)
f1_train_00011 = f1_score(Labels_train, KM5_pred_train_00011)
f1_train_00100 = f1_score(Labels_train, KM5_pred_train_00100)
f1_train_00101 = f1_score(Labels_train, KM5_pred_train_00101)
f1_train_00110 = f1_score(Labels_train, KM5_pred_train_00110)
f1_train_00111 = f1_score(Labels_train, KM5_pred_train_00111)
f1_train_01000 = f1_score(Labels_train, KM5_pred_train_01000)
f1_train_01001 = f1_score(Labels_train, KM5_pred_train_01001)
f1_train_01010 = f1_score(Labels_train, KM5_pred_train_01010)
f1_train_01011 = f1_score(Labels_train, KM5_pred_train_01011)
f1_train_01100 = f1_score(Labels_train, KM5_pred_train_01100)
f1_train_01101 = f1_score(Labels_train, KM5_pred_train_01101)
f1_train_01110 = f1_score(Labels_train, KM5_pred_train_01110)
f1_train_01111 = f1_score(Labels_train, KM5_pred_train_01111)
f1_train_10000 = f1_score(Labels_train, KM5_pred_train_10000)
f1_train_10001 = f1_score(Labels_train, KM5_pred_train_10001)
f1_train_10010 = f1_score(Labels_train, KM5_pred_train_10010)
f1_train_10011 = f1_score(Labels_train, KM5_pred_train_10011)
f1_train_10100 = f1_score(Labels_train, KM5_pred_train_10100)
f1_train_10101 = f1_score(Labels_train, KM5_pred_train_10101)
f1_train_10110 = f1_score(Labels_train, KM5_pred_train_10110)
f1_train_10111 = f1_score(Labels_train, KM5_pred_train_10111)
f1_train_11000 = f1_score(Labels_train, KM5_pred_train_11000)
f1_train_11001 = f1_score(Labels_train, KM5_pred_train_11001)
f1_train_11010 = f1_score(Labels_train, KM5_pred_train_11010)
f1_train_11011 = f1_score(Labels_train, KM5_pred_train_11011)
f1_train_11100 = f1_score(Labels_train, KM5_pred_train_11100)
f1_train_11101 = f1_score(Labels_train, KM5_pred_train_11101)
f1_train_11110 = f1_score(Labels_train, KM5_pred_train_11110)

KM5_tr_acc_list = [accuracy_train_00001, accuracy_train_00010, accuracy_train_00011, accuracy_train_00100, 
                   accuracy_train_00101, accuracy_train_00110, accuracy_train_00111, accuracy_train_01000, 
                   accuracy_train_01001, accuracy_train_01010, 
                   accuracy_train_01011, accuracy_train_01100, accuracy_train_01101, accuracy_train_01110, 
                   accuracy_train_01111,
                   accuracy_train_10000, accuracy_train_10001, accuracy_train_10010, accuracy_train_10011, 
                   accuracy_train_10100, accuracy_train_10101, accuracy_train_10110, accuracy_train_10111,
                   accuracy_train_11000, accuracy_train_11001, accuracy_train_11010, 
                   accuracy_train_11011, accuracy_train_11100, 
                   accuracy_train_11101, accuracy_train_11110]

print(KM5_tr_acc_list)

KM5_tr_f1_list = [f1_train_00001, f1_train_00010, f1_train_00011, f1_train_00100, 
                   f1_train_00101, f1_train_00110, f1_train_00111, f1_train_01000, 
                   f1_train_01001, f1_train_01010, 
                   f1_train_01011, f1_train_01100, f1_train_01101, f1_train_01110, 
                   f1_train_01111,
                   f1_train_10000, f1_train_10001, f1_train_10010, f1_train_10011, 
                   f1_train_10100, f1_train_10101, f1_train_10110, f1_train_10111,
                   f1_train_11000, f1_train_11001, f1_train_11010, 
                   f1_train_11011, f1_train_11100, 
                   f1_train_11101, f1_train_11110]

KM5_pred_train_list = [KM5_pred_train_00001, KM5_pred_train_00010, KM5_pred_train_00011, KM5_pred_train_00100, 
                   KM5_pred_train_00101, KM5_pred_train_00110, KM5_pred_train_00111, KM5_pred_train_01000, 
                   KM5_pred_train_01001, KM5_pred_train_01010, 
                   KM5_pred_train_01011, KM5_pred_train_01100, KM5_pred_train_01101, KM5_pred_train_01110, 
                   KM5_pred_train_01111,
                   KM5_pred_train_10000, KM5_pred_train_10001, KM5_pred_train_10010, KM5_pred_train_10011, 
                   KM5_pred_train_10100, KM5_pred_train_10101, KM5_pred_train_10110, KM5_pred_train_10111,
                   KM5_pred_train_11000, KM5_pred_train_11001, KM5_pred_train_11010, 
                   KM5_pred_train_11011, KM5_pred_train_11100, 
                   KM5_pred_train_11101, KM5_pred_train_11110]

KM5_pred_val_list = [KM5_pred_val_00001, KM5_pred_val_00010, KM5_pred_val_00011, KM5_pred_val_00100, 
                   KM5_pred_val_00101, KM5_pred_val_00110, KM5_pred_val_00111, KM5_pred_val_01000, 
                   KM5_pred_val_01001, KM5_pred_val_01010, 
                   KM5_pred_val_01011, KM5_pred_val_01100, KM5_pred_val_01101, KM5_pred_val_01110, 
                   KM5_pred_val_01111,
                   KM5_pred_val_10000, KM5_pred_val_10001, KM5_pred_val_10010, KM5_pred_val_10011, 
                   KM5_pred_val_10100, KM5_pred_val_10101, KM5_pred_val_10110, KM5_pred_val_10111,
                   KM5_pred_val_11000, KM5_pred_val_11001, KM5_pred_val_11010, 
                   KM5_pred_val_11011, KM5_pred_val_11100, 
                   KM5_pred_val_11101, KM5_pred_val_11110]

#Finds best accuracy model
max_accuracy_KM5_train = max(KM5_tr_acc_list)
max_f1_KM5_train = max(KM5_tr_f1_list)
max_index_KM5 = KM5_tr_acc_list.index(max_accuracy_KM5_train)

KM5_pred_train = KM5_pred_train_list[max_index_KM5]
KM5_pred_val = KM5_pred_val_list[max_index_KM5]
    

    

accuracy_train = accuracy_score(Labels_train, KM5_pred_train)
confmat_train = confusion_matrix(Labels_train, KM5_pred_train)
f1_train = f1_score(Labels_train, KM5_pred_train)
mcc_train = matthews_corrcoef(Labels_train, KM5_pred_train)

accuracy = accuracy_score(Labels_val, KM5_pred_val)
confmat = confusion_matrix(Labels_val, KM5_pred_val)
f1 = f1_score(Labels_val, KM5_pred_val)
mcc = matthews_corrcoef(Labels_val, KM5_pred_val)

print("Confusion matrix for training set:\n")
plot_confusion_matrix(Labels_train, KM5_pred_train, ["beam","reaction"])
print("Accuracy:", accuracy_train)
print("F1-score:", f1_train)
print("MCC:", mcc_train)


print("Confusion matrix for validation set:\n")
plot_confusion_matrix(Labels_val, KM5_pred_val, ["beam","reaction"])
print("Accuracy:", accuracy)
print("F1-score:", f1)
print("MCC:", mcc)
print(confmat)
# Out:
# [1 2 1 ... 1 2 1]
# [0.3498452012383901, 0.3752321981424149, 0.23157894736842105, 0.3938080495356037, 0.2501547987616099, 0.2755417956656347, 0.13188854489164087, 0.9919504643962849, 0.848297213622291, 0.8736842105263158, 0.730030959752322, 0.8922600619195047, 0.7486068111455109, 0.7739938080495357, 0.6303405572755418, 0.3696594427244582, 0.2260061919504644, 0.2513931888544892, 0.10773993808049535, 0.26996904024767804, 0.12631578947368421, 0.15170278637770898, 0.00804953560371517, 0.8681114551083592, 0.7244582043343654, 0.74984520123839, 0.6061919504643963, 0.7684210526315789, 0.6247678018575852, 0.6501547987616099]
# Confusion matrix for training set:
# Accuracy: 0.9919504643962849
# F1-score: 0.9920683343502136
# MCC: 0.9839042214078676
# Confusion matrix for validation set:
# Accuracy: 0.5222222222222223
# F1-score: 0.5057471264367817
# MCC: 0.04351051876508937
# [[50 42]
#  [44 44]]

# %% [markdown]
# ### Support Vector Machine
# Here we use a support vector machine. As in the random forest case, the optimal parameters are determined using gridsearch.

# %%
from sklearn.metrics import classification_report
from sklearn import svm

#Simplest method
#SVM = svm.SVC(kernel='rbf') #other options (poly,sigmoid,linear)
#SVM.fit(xSimple_train_stsc,Labels_train)

#SVM_pred_train = SVM.predict(xSimple_train_stsc)
#SVM_pred_val = SVM.predict(xSimple_val_stsc)


#Using grid search

# Set the parameters by cross-validation
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                     'C': [1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000]},
                    {'kernel': ['poly'], 'C': [1, 10, 100, 1000], 'degree': [2,3,4], 'coef0': [0.,0.001,0.01,0.1,1,10]},
                   {'kernel': ['sigmoid'], 'C': [1, 10, 100, 1000], 'coef0': [0.,0.001,0.01,0.1,1,10]}]

#select a metric to choose best SVM (comment one or the other)

#score = 'precision'
score = 'recall'


print("# Tuning hyper-parameters for %s" % score)
print()

SVM = GridSearchCV(
    svm.SVC(), tuned_parameters, cv=5, scoring='%s_macro' % score
)
SVM.fit(xSimple_train_stsc,Labels_train)

print("Best parameters set found on training set for %s:" % score)
print()
print(SVM.best_params_)
print()
print("Grid scores on training set:")
print()
means = SVM.cv_results_['mean_test_score']
stds = SVM.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, SVM.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
print()

SVM_pred_train = SVM.predict(xSimple_train_stsc)
SVM_pred_val = SVM.predict(xSimple_val_stsc)

accuracy_train = accuracy_score(Labels_train, SVM_pred_train)
confmat_train = confusion_matrix(Labels_train, SVM_pred_train)
f1_train = f1_score(Labels_train, SVM_pred_train)
mcc_train = matthews_corrcoef(Labels_train, SVM_pred_train)

accuracy = accuracy_score(Labels_val, SVM_pred_val)
confmat = confusion_matrix(Labels_val, SVM_pred_val)
f1 = f1_score(Labels_val, SVM_pred_val)
mcc = matthews_corrcoef(Labels_val, SVM_pred_val)

print("Confusion matrix for training set:\n")
plot_confusion_matrix(Labels_train, SVM_pred_train, ["beam","reaction"])
print("Accuracy:", accuracy_train)
print("F1-score:", f1_train)
print("MCC:", mcc_train)

print("Confusion matrix for validation set:\n")
plot_confusion_matrix(Labels_val, SVM_pred_val, ["beam","reaction"])
print("Accuracy:", accuracy)
print("F1-score:", f1)
print("MCC:", mcc)
print(confmat)
# Out:
# # Tuning hyper-parameters for recall
#
# Best parameters set found on training set for recall:
#
# {'C': 10, 'coef0': 0.0, 'kernel': 'sigmoid'}
#
# Grid scores on training set:
#
# 0.989 (+/-0.011) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.839 (+/-0.030) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.993 (+/-0.009) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.989 (+/-0.011) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.994 (+/-0.010) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.993 (+/-0.009) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.995 (+/-0.010) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.994 (+/-0.010) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.994 (+/-0.010) for {'C': 1, 'kernel': 'linear'}
# 0.996 (+/-0.008) for {'C': 10, 'kernel': 'linear'}
# 0.996 (+/-0.008) for {'C': 100, 'kernel': 'linear'}
# 0.995 (+/-0.007) for {'C': 1000, 'kernel': 'linear'}
# 0.971 (+/-0.015) for {'C': 1, 'coef0': 0.0, 'degree': 2, 'kernel': 'poly'}
# 0.968 (+/-0.020) for {'C': 1, 'coef0': 0.0, 'degree': 3, 'kernel': 'poly'}
# 0.944 (+/-0.020) for {'C': 1, 'coef0': 0.0, 'degree': 4, 'kernel': 'poly'}
# 0.972 (+/-0.014) for {'C': 1, 'coef0': 0.001, 'degree': 2, 'kernel': 'poly'}
# 0.968 (+/-0.020) for {'C': 1, 'coef0': 0.001, 'degree': 3, 'kernel': 'poly'}
# 0.944 (+/-0.020) for {'C': 1, 'coef0': 0.001, 'degree': 4, 'kernel': 'poly'}
# 0.979 (+/-0.014) for {'C': 1, 'coef0': 0.01, 'degree': 2, 'kernel': 'poly'}
# 0.970 (+/-0.020) for {'C': 1, 'coef0': 0.01, 'degree': 3, 'kernel': 'poly'}
# 0.947 (+/-0.023) for {'C': 1, 'coef0': 0.01, 'degree': 4, 'kernel': 'poly'}
# 0.994 (+/-0.010) for {'C': 1, 'coef0': 0.1, 'degree': 2, 'kernel': 'poly'}
# 0.989 (+/-0.009) for {'C': 1, 'coef0': 0.1, 'degree': 3, 'kernel': 'poly'}
# 0.971 (+/-0.016) for {'C': 1, 'coef0': 0.1, 'degree': 4, 'kernel': 'poly'}
# 0.995 (+/-0.010) for {'C': 1, 'coef0': 1, 'degree': 2, 'kernel': 'poly'}
# 0.994 (+/-0.010) for {'C': 1, 'coef0': 1, 'degree': 3, 'kernel': 'poly'}
# 0.994 (+/-0.011) for {'C': 1, 'coef0': 1, 'degree': 4, 'kernel': 'poly'}
# 0.995 (+/-0.010) for {'C': 1, 'coef0': 10, 'degree': 2, 'kernel': 'poly'}
# 0.994 (+/-0.006) for {'C': 1, 'coef0': 10, 'degree': 3, 'kernel': 'poly'}
# 0.989 (+/-0.005) for {'C': 1, 'coef0': 10, 'degree': 4, 'kernel': 'poly'}
# 0.984 (+/-0.014) for {'C': 10, 'coef0': 0.0, 'degree': 2, 'kernel': 'poly'}
# 0.981 (+/-0.016) for {'C': 10, 'coef0': 0.0, 'degree': 3, 'kernel': 'poly'}
# 0.962 (+/-0.019) for {'C': 10, 'coef0': 0.0, 'degree': 4, 'kernel': 'poly'}
# 0.986 (+/-0.009) for {'C': 10, 'coef0': 0.001, 'degree': 2, 'kernel': 'poly'}
# 0.981 (+/-0.016) for {'C': 10, 'coef0': 0.001, 'degree': 3, 'kernel': 'poly'}
# 0.963 (+/-0.019) for {'C': 10, 'coef0': 0.001, 'degree': 4, 'kernel': 'poly'}
# 0.991 (+/-0.009) for {'C': 10, 'coef0': 0.01, 'degree': 2, 'kernel': 'poly'}
# 0.984 (+/-0.013) for {'C': 10, 'coef0': 0.01, 'degree': 3, 'kernel': 'poly'}
# 0.966 (+/-0.019) for {'C': 10, 'coef0': 0.01, 'degree': 4, 'kernel': 'poly'}
# 0.994 (+/-0.009) for {'C': 10, 'coef0': 0.1, 'degree': 2, 'kernel': 'poly'}
# 0.993 (+/-0.007) for {'C': 10, 'coef0': 0.1, 'degree': 3, 'kernel': 'poly'}
# 0.994 (+/-0.009) for {'C': 10, 'coef0': 0.1, 'degree': 4, 'kernel': 'poly'}
# 0.994 (+/-0.010) for {'C': 10, 'coef0': 1, 'degree': 2, 'kernel': 'poly'}
# 0.994 (+/-0.009) for {'C': 10, 'coef0': 1, 'degree': 3, 'kernel': 'poly'}
# 0.991 (+/-0.009) for {'C': 10, 'coef0': 1, 'degree': 4, 'kernel': 'poly'}
# 0.995 (+/-0.007) for {'C': 10, 'coef0': 10, 'degree': 2, 'kernel': 'poly'}
# 0.991 (+/-0.008) for {'C': 10, 'coef0': 10, 'degree': 3, 'kernel': 'poly'}
# 0.988 (+/-0.007) for {'C': 10, 'coef0': 10, 'degree': 4, 'kernel': 'poly'}
# 0.984 (+/-0.010) for {'C': 100, 'coef0': 0.0, 'degree': 2, 'kernel': 'poly'}
# 0.994 (+/-0.011) for {'C': 100, 'coef0': 0.0, 'degree': 3, 'kernel': 'poly'}
# 0.975 (+/-0.011) for {'C': 100, 'coef0': 0.0, 'degree': 4, 'kernel': 'poly'}
# 0.991 (+/-0.006) for {'C': 100, 'coef0': 0.001, 'degree': 2, 'kernel': 'poly'}
# 0.994 (+/-0.010) for {'C': 100, 'coef0': 0.001, 'degree': 3, 'kernel': 'poly'}
# 0.976 (+/-0.010) for {'C': 100, 'coef0': 0.001, 'degree': 4, 'kernel': 'poly'}
# 0.993 (+/-0.007) for {'C': 100, 'coef0': 0.01, 'degree': 2, 'kernel': 'poly'}
# 0.993 (+/-0.010) for {'C': 100, 'coef0': 0.01, 'degree': 3, 'kernel': 'poly'}
# 0.989 (+/-0.005) for {'C': 100, 'coef0': 0.01, 'degree': 4, 'kernel': 'poly'}
# 0.996 (+/-0.006) for {'C': 100, 'coef0': 0.1, 'degree': 2, 'kernel': 'poly'}
# 0.992 (+/-0.007) for {'C': 100, 'coef0': 0.1, 'degree': 3, 'kernel': 'poly'}
# 0.991 (+/-0.004) for {'C': 100, 'coef0': 0.1, 'degree': 4, 'kernel': 'poly'}
# 0.994 (+/-0.005) for {'C': 100, 'coef0': 1, 'degree': 2, 'kernel': 'poly'}
# 0.991 (+/-0.007) for {'C': 100, 'coef0': 1, 'degree': 3, 'kernel': 'poly'}
# 0.991 (+/-0.007) for {'C': 100, 'coef0': 1, 'degree': 4, 'kernel': 'poly'}
# 0.994 (+/-0.005) for {'C': 100, 'coef0': 10, 'degree': 2, 'kernel': 'poly'}
# 0.989 (+/-0.008) for {'C': 100, 'coef0': 10, 'degree': 3, 'kernel': 'poly'}
# 0.988 (+/-0.007) for {'C': 100, 'coef0': 10, 'degree': 4, 'kernel': 'poly'}
# 0.987 (+/-0.006) for {'C': 1000, 'coef0': 0.0, 'degree': 2, 'kernel': 'poly'}
# 0.990 (+/-0.013) for {'C': 1000, 'coef0': 0.0, 'degree': 3, 'kernel': 'poly'}
# 0.991 (+/-0.006) for {'C': 1000, 'coef0': 0.0, 'degree': 4, 'kernel': 'poly'}
# 0.993 (+/-0.007) for {'C': 1000, 'coef0': 0.001, 'degree': 2, 'kernel': 'poly'}
# 0.991 (+/-0.011) for {'C': 1000, 'coef0': 0.001, 'degree': 3, 'kernel': 'poly'}
# 0.989 (+/-0.009) for {'C': 1000, 'coef0': 0.001, 'degree': 4, 'kernel': 'poly'}
# 0.993 (+/-0.007) for {'C': 1000, 'coef0': 0.01, 'degree': 2, 'kernel': 'poly'}
# 0.990 (+/-0.009) for {'C': 1000, 'coef0': 0.01, 'degree': 3, 'kernel': 'poly'}
# 0.990 (+/-0.006) for {'C': 1000, 'coef0': 0.01, 'degree': 4, 'kernel': 'poly'}
# 0.993 (+/-0.008) for {'C': 1000, 'coef0': 0.1, 'degree': 2, 'kernel': 'poly'}
# 0.989 (+/-0.006) for {'C': 1000, 'coef0': 0.1, 'degree': 3, 'kernel': 'poly'}
# 0.991 (+/-0.005) for {'C': 1000, 'coef0': 0.1, 'degree': 4, 'kernel': 'poly'}
# 0.990 (+/-0.008) for {'C': 1000, 'coef0': 1, 'degree': 2, 'kernel': 'poly'}
# 0.988 (+/-0.005) for {'C': 1000, 'coef0': 1, 'degree': 3, 'kernel': 'poly'}
# 0.990 (+/-0.005) for {'C': 1000, 'coef0': 1, 'degree': 4, 'kernel': 'poly'}
# 0.990 (+/-0.008) for {'C': 1000, 'coef0': 10, 'degree': 2, 'kernel': 'poly'}
# 0.989 (+/-0.008) for {'C': 1000, 'coef0': 10, 'degree': 3, 'kernel': 'poly'}
# 0.988 (+/-0.007) for {'C': 1000, 'coef0': 10, 'degree': 4, 'kernel': 'poly'}
# 0.993 (+/-0.009) for {'C': 1, 'coef0': 0.0, 'kernel': 'sigmoid'}
# 0.993 (+/-0.009) for {'C': 1, 'coef0': 0.001, 'kernel': 'sigmoid'}
# 0.993 (+/-0.008) for {'C': 1, 'coef0': 0.01, 'kernel': 'sigmoid'}
# 0.993 (+/-0.008) for {'C': 1, 'coef0': 0.1, 'kernel': 'sigmoid'}
# 0.988 (+/-0.009) for {'C': 1, 'coef0': 1, 'kernel': 'sigmoid'}
# 0.500 (+/-0.000) for {'C': 1, 'coef0': 10, 'kernel': 'sigmoid'}
# 0.996 (+/-0.005) for {'C': 10, 'coef0': 0.0, 'kernel': 'sigmoid'}
# 0.996 (+/-0.005) for {'C': 10, 'coef0': 0.001, 'kernel': 'sigmoid'}
# 0.995 (+/-0.006) for {'C': 10, 'coef0': 0.01, 'kernel': 'sigmoid'}
# 0.994 (+/-0.008) for {'C': 10, 'coef0': 0.1, 'kernel': 'sigmoid'}
# 0.970 (+/-0.019) for {'C': 10, 'coef0': 1, 'kernel': 'sigmoid'}
# 0.500 (+/-0.000) for {'C': 10, 'coef0': 10, 'kernel': 'sigmoid'}
# 0.993 (+/-0.011) for {'C': 100, 'coef0': 0.0, 'kernel': 'sigmoid'}
# 0.993 (+/-0.011) for {'C': 100, 'coef0': 0.001, 'kernel': 'sigmoid'}
# 0.993 (+/-0.011) for {'C': 100, 'coef0': 0.01, 'kernel': 'sigmoid'}
# 0.990 (+/-0.014) for {'C': 100, 'coef0': 0.1, 'kernel': 'sigmoid'}
# 0.967 (+/-0.021) for {'C': 100, 'coef0': 1, 'kernel': 'sigmoid'}
# 0.500 (+/-0.000) for {'C': 100, 'coef0': 10, 'kernel': 'sigmoid'}
# 0.993 (+/-0.011) for {'C': 1000, 'coef0': 0.0, 'kernel': 'sigmoid'}
# 0.993 (+/-0.011) for {'C': 1000, 'coef0': 0.001, 'kernel': 'sigmoid'}
# 0.993 (+/-0.011) for {'C': 1000, 'coef0': 0.01, 'kernel': 'sigmoid'}
# 0.990 (+/-0.014) for {'C': 1000, 'coef0': 0.1, 'kernel': 'sigmoid'}
# 0.967 (+/-0.021) for {'C': 1000, 'coef0': 1, 'kernel': 'sigmoid'}
# 0.500 (+/-0.000) for {'C': 1000, 'coef0': 10, 'kernel': 'sigmoid'}
#
# Confusion matrix for training set:
# Accuracy: 0.993188854489164
# F1-score: 0.9932721712538227
# MCC: 0.9863763813442127
# Confusion matrix for validation set:
# Accuracy: 0.9944444444444445
# F1-score: 0.9942857142857142
# MCC: 0.9889417905532354
# [[92  0]
#  [ 1 87]]

# %% [markdown]
# ### DEMOCRACY
# Here we let each method (linear regression, DNN, K-means and Random Forest) vote for the classification

# %%
#TotalVotesTrain = DNN_pred_train + KM_pred_train + LR_pred_train + RFC_pred_train
#TotalVotesVal = DNN_pred_val + KM_pred_val + LR_pred_val + RFC_pred_val
Vote_pred_train = np.zeros(len(DNN_pred_train ))
Vote_pred_val = np.zeros(len(DNN_pred_val ))

for i in range(len(DNN_pred_train)):
    TotalVotesTrain = DNN_pred_train[i] + KM3_pred_train[i] + LR_pred_train[i] + RFC_pred_train[i] + SVM_pred_train[i]
    if TotalVotesTrain > 2:
        Vote_pred_train[i] = 1
    else:
        Vote_pred_train[i] = 0
for i in range(len(DNN_pred_val)):
    TotalVotesVal = DNN_pred_val[i] + KM3_pred_val[i] + LR_pred_val[i] + RFC_pred_val[i] + SVM_pred_val[i]
    if TotalVotesVal > 2:
        Vote_pred_val[i] = 1
    else:
        Vote_pred_val[i] = 0
    
accuracy_train = accuracy_score(Labels_train, Vote_pred_train)
confmat_train = confusion_matrix(Labels_train, Vote_pred_train)
f1_train = f1_score(Labels_train, Vote_pred_train)
mcc_train = matthews_corrcoef(Labels_train, Vote_pred_train)

accuracy = accuracy_score(Labels_val, Vote_pred_val)
confmat = confusion_matrix(Labels_val, Vote_pred_val)
f1 = f1_score(Labels_val, Vote_pred_val)
mcc = matthews_corrcoef(Labels_val, Vote_pred_val)

print("Confusion matrix for training set:\n")
plot_confusion_matrix(Labels_train, Vote_pred_train, ["beam","reaction"])
print("Accuracy:", accuracy_train)
print("F1-score:", f1_train)
print("MCC:", mcc_train)
print(RFC_pred_train)

print("Confusion matrix for validation set:\n")
plot_confusion_matrix(Labels_val, Vote_pred_val, ["beam","reaction"])
print("Accuracy:", accuracy)
print("F1-score:", f1)
print("MCC:", mcc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-c09ceb199b7c> in <module>
#       1 #TotalVotesTrain = DNN_pred_train + KM_pred_train + LR_pred_train + RFC_pred_train
#       2 #TotalVotesVal = DNN_pred_val + KM_pred_val + LR_pred_val + RFC_pred_val
# ----> 3 Vote_pred_train = np.zeros(len(DNN_pred_train ))
#       4 Vote_pred_val = np.zeros(len(DNN_pred_val ))
#       5
#
# NameError: name 'DNN_pred_train' is not defined

# %% [markdown]
# ### Misclassified Event (training set)
# Here we find and plot all events in the training set that were misclassified using the democratic voting above

# %%
misclassified_events_train = train_idx[Labels_train != Vote_pred_train]

print(misclassified_events_train)

for i in(misclassified_events_train):
    plot_3d_event(AllData,Labels,i)

# %%
#data_origin = 'https://github.com/NuclearTalent/MachineLearningECT/raw/master/doc/ProjectsExercises/2020/ProjectAT/pdf/Mg22_alphaalpha_digiSim.h5'

#data_path = tf.keras.utils.get_file('Mg22_alphaalpha_digiSim.h5', origin=data_origin)
#h5 = h5py.File(data_path, 'r')

# %% [markdown]
# # Unsupervised clustering with Autoencoders

# %% [markdown]
# When applying clustering algorithms such as kMeans we have to take into account that usually these algorithms perform better in a low dimensional space. Given this "constraint" is possibile to put a dimensionality reduction phase before the clustering one. In order to do so we can use Autoencoders in order to learn a lower dimensionality representation of our input features and then using a clustering algorithm such as kMeans on this lower dimensional space (also referred as Latent Space).

# %% [markdown]
# An Autoencoder is a kind of neural networks which is trained to reproduce the input vector. We can picture this kind of networks as built of two main part:
# 1. Encoder, $h=f(x)$
# 2. Decoder, $r=g(h)$
#
# If the dimensionality of the input vector $\vec{x}$ is higher than the hidden encoding layer $\vec{h}$ the autoencoder is called $\textbf{undercomplete}$.
# We can use this type of network in order to learn a lower dimensionality representation of our data, in fact, while training the network in order to learn the mapping $g(f(x))=x$ the
# encoder network should learn a meaningful representation of our data which ensure the reconstruction through the decoder network.
#
#
# <img src="img/autoencoder.png" width=600;>
#
#
# If our data shows clusters in Latent space we are confident that our network has learned a good lower dimensionality representation of our data.

# %%
# Building the autoencoder

autoencoder = keras.Sequential()

# Input Layer
autoencoder.add(keras.Input(shape=(5,)))

# Encoder Part
autoencoder.add(layers.Dense(3,activation='sigmoid', name='Encoder1'))
autoencoder.add(layers.Dense(2,activation='sigmoid', name='Encoder2'))
# Decoder Part
autoencoder.add(layers.Dense(3,activation='sigmoid', name='Decoder1'))
autoencoder.add(layers.Dense(5,activation='sigmoid', name='Decoder2'))

autoencoder.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoder1 (Dense)             (None, 3)                 18
# _________________________________________________________________
# Encoder2 (Dense)             (None, 2)                 8
# _________________________________________________________________
# Decoder1 (Dense)             (None, 3)                 9
# _________________________________________________________________
# Decoder2 (Dense)             (None, 5)                 20
# =================================================================
# Total params: 55
# Trainable params: 55
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Let's use as optimizer adam with the following parameters:
# 1. Learning rate: $10^{-3}$
# 2. $\beta_1 = 0.99$
# 3. $\beta_2 = 0.999$
#
# As loss function we use the Mean Squared Error.

# %%
# Compiling Model
autoencoder.compile(
        optimizer = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.99, beta_2=0.999),
        loss      = keras.losses.MeanSquaredError(),
        metrics   = [keras.metrics.MeanSquaredError()]
    )

# %% [markdown]
# For this example we normalize our dataset using the Min-Max Scaling

# %%
# Normalize data using Min-Max normalization
xSimple[:,0] = ( xSimple[:,0] - xSimple[:,0].min() ) / (xSimple[:,0].max() - xSimple[:,0].min() )
xSimple[:,1] = ( xSimple[:,1] - xSimple[:,1].min() ) / (xSimple[:,1].max() - xSimple[:,1].min() )
xSimple[:,2] = ( xSimple[:,2] - xSimple[:,2].min() ) / (xSimple[:,2].max() - xSimple[:,2].min() )
xSimple[:,3] = ( xSimple[:,3] - xSimple[:,3].min() ) / (xSimple[:,3].max() - xSimple[:,3].min() )
xSimple[:,4] = ( xSimple[:,4] - xSimple[:,4].min() ) / (xSimple[:,4].max() - xSimple[:,4].min() )


xSimple_train = xSimple[train_idx][:]
xSimple_val = xSimple[val_idx][:]
xSimple_test = xSimple[test_idx][:]
Labels_train = Labels[train_idx]
Labels_val = Labels[val_idx]
Labels_test = Labels[test_idx]

# %%
# Training The Model

history = autoencoder.fit(
                            xSimple_train,
                            xSimple_train,
                            validation_data = (xSimple_val,xSimple_val),
                            batch_size=64,
                            epochs=300
                         )
# Out:
# Epoch 1/300
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0730 - mean_squared_error: 0.0730 - val_loss: 0.0699 - val_mean_squared_error: 0.0699
# Epoch 2/300
# 26/26 [==============================] - 0s 866us/step - loss: 0.0686 - mean_squared_error: 0.0686 - val_loss: 0.0656 - val_mean_squared_error: 0.0656
# Epoch 3/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0645 - mean_squared_error: 0.0645 - val_loss: 0.0617 - val_mean_squared_error: 0.0617
# Epoch 4/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0608 - mean_squared_error: 0.0608 - val_loss: 0.0581 - val_mean_squared_error: 0.0581
# Epoch 5/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0575 - mean_squared_error: 0.0575 - val_loss: 0.0550 - val_mean_squared_error: 0.0550
# Epoch 6/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0545 - mean_squared_error: 0.0545 - val_loss: 0.0521 - val_mean_squared_error: 0.0521
# Epoch 7/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0519 - mean_squared_error: 0.0519 - val_loss: 0.0497 - val_mean_squared_error: 0.0497
# Epoch 8/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0497 - mean_squared_error: 0.0497 - val_loss: 0.0475 - val_mean_squared_error: 0.0475
# Epoch 9/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0477 - mean_squared_error: 0.0477 - val_loss: 0.0457 - val_mean_squared_error: 0.0457
# Epoch 10/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0460 - mean_squared_error: 0.0460 - val_loss: 0.0442 - val_mean_squared_error: 0.0442
# Epoch 11/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0446 - mean_squared_error: 0.0446 - val_loss: 0.0429 - val_mean_squared_error: 0.0429
# Epoch 12/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0419 - val_mean_squared_error: 0.0419
# Epoch 13/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0426 - mean_squared_error: 0.0426 - val_loss: 0.0410 - val_mean_squared_error: 0.0410
# Epoch 14/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0418 - mean_squared_error: 0.0418 - val_loss: 0.0403 - val_mean_squared_error: 0.0403
# Epoch 15/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0411 - mean_squared_error: 0.0411 - val_loss: 0.0398 - val_mean_squared_error: 0.0398
# Epoch 16/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0406 - mean_squared_error: 0.0406 - val_loss: 0.0393 - val_mean_squared_error: 0.0393
# Epoch 17/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0402 - mean_squared_error: 0.0402 - val_loss: 0.0390 - val_mean_squared_error: 0.0390
# Epoch 18/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0399 - mean_squared_error: 0.0399 - val_loss: 0.0388 - val_mean_squared_error: 0.0388
# Epoch 19/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0397 - mean_squared_error: 0.0397 - val_loss: 0.0386 - val_mean_squared_error: 0.0386
# Epoch 20/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0395 - mean_squared_error: 0.0395 - val_loss: 0.0385 - val_mean_squared_error: 0.0385
# Epoch 21/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0394 - mean_squared_error: 0.0394 - val_loss: 0.0384 - val_mean_squared_error: 0.0384
# Epoch 22/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0393 - mean_squared_error: 0.0393 - val_loss: 0.0383 - val_mean_squared_error: 0.0383
# Epoch 23/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0392 - mean_squared_error: 0.0392 - val_loss: 0.0383 - val_mean_squared_error: 0.0383
# Epoch 24/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0392 - mean_squared_error: 0.0392 - val_loss: 0.0382 - val_mean_squared_error: 0.0382
# Epoch 25/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0391 - mean_squared_error: 0.0391 - val_loss: 0.0382 - val_mean_squared_error: 0.0382
# Epoch 26/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0391 - mean_squared_error: 0.0391 - val_loss: 0.0382 - val_mean_squared_error: 0.0382
# Epoch 27/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0391 - mean_squared_error: 0.0391 - val_loss: 0.0381 - val_mean_squared_error: 0.0381
# Epoch 28/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0391 - mean_squared_error: 0.0391 - val_loss: 0.0381 - val_mean_squared_error: 0.0381
# Epoch 29/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0390 - mean_squared_error: 0.0390 - val_loss: 0.0381 - val_mean_squared_error: 0.0381
# Epoch 30/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0390 - mean_squared_error: 0.0390 - val_loss: 0.0381 - val_mean_squared_error: 0.0381
# Epoch 31/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0390 - mean_squared_error: 0.0390 - val_loss: 0.0381 - val_mean_squared_error: 0.0381
# Epoch 32/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0390 - mean_squared_error: 0.0390 - val_loss: 0.0381 - val_mean_squared_error: 0.0381
# Epoch 33/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0390 - mean_squared_error: 0.0390 - val_loss: 0.0381 - val_mean_squared_error: 0.0381
# Epoch 34/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0390 - mean_squared_error: 0.0390 - val_loss: 0.0380 - val_mean_squared_error: 0.0380
# Epoch 35/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0390 - mean_squared_error: 0.0390 - val_loss: 0.0380 - val_mean_squared_error: 0.0380
# Epoch 36/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0390 - mean_squared_error: 0.0390 - val_loss: 0.0380 - val_mean_squared_error: 0.0380
# Epoch 37/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0389 - mean_squared_error: 0.0389 - val_loss: 0.0380 - val_mean_squared_error: 0.0380
# Epoch 38/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0389 - mean_squared_error: 0.0389 - val_loss: 0.0380 - val_mean_squared_error: 0.0380
# Epoch 39/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0389 - mean_squared_error: 0.0389 - val_loss: 0.0380 - val_mean_squared_error: 0.0380
# Epoch 40/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0389 - mean_squared_error: 0.0389 - val_loss: 0.0380 - val_mean_squared_error: 0.0380
# Epoch 41/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0389 - mean_squared_error: 0.0389 - val_loss: 0.0380 - val_mean_squared_error: 0.0380
# Epoch 42/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0389 - mean_squared_error: 0.0389 - val_loss: 0.0379 - val_mean_squared_error: 0.0379
# Epoch 43/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0389 - mean_squared_error: 0.0389 - val_loss: 0.0379 - val_mean_squared_error: 0.0379
# Epoch 44/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0388 - mean_squared_error: 0.0388 - val_loss: 0.0379 - val_mean_squared_error: 0.0379
# Epoch 45/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0388 - mean_squared_error: 0.0388 - val_loss: 0.0379 - val_mean_squared_error: 0.0379
# Epoch 46/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0388 - mean_squared_error: 0.0388 - val_loss: 0.0379 - val_mean_squared_error: 0.0379
# Epoch 47/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0388 - mean_squared_error: 0.0388 - val_loss: 0.0378 - val_mean_squared_error: 0.0378
# Epoch 48/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0388 - mean_squared_error: 0.0388 - val_loss: 0.0378 - val_mean_squared_error: 0.0378
# Epoch 49/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0387 - mean_squared_error: 0.0387 - val_loss: 0.0378 - val_mean_squared_error: 0.0378
# Epoch 50/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0387 - mean_squared_error: 0.0387 - val_loss: 0.0378 - val_mean_squared_error: 0.0378
# Epoch 51/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0387 - mean_squared_error: 0.0387 - val_loss: 0.0377 - val_mean_squared_error: 0.0377
# Epoch 52/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0386 - mean_squared_error: 0.0386 - val_loss: 0.0377 - val_mean_squared_error: 0.0377
# Epoch 53/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0386 - mean_squared_error: 0.0386 - val_loss: 0.0377 - val_mean_squared_error: 0.0377
# Epoch 54/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0385 - mean_squared_error: 0.0385 - val_loss: 0.0376 - val_mean_squared_error: 0.0376
# Epoch 55/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0385 - mean_squared_error: 0.0385 - val_loss: 0.0376 - val_mean_squared_error: 0.0376
# Epoch 56/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0384 - mean_squared_error: 0.0384 - val_loss: 0.0375 - val_mean_squared_error: 0.0375
# Epoch 57/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0384 - mean_squared_error: 0.0384 - val_loss: 0.0374 - val_mean_squared_error: 0.0374
# Epoch 58/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0383 - mean_squared_error: 0.0383 - val_loss: 0.0374 - val_mean_squared_error: 0.0374
# Epoch 59/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0382 - mean_squared_error: 0.0382 - val_loss: 0.0373 - val_mean_squared_error: 0.0373
# Epoch 60/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0382 - mean_squared_error: 0.0382 - val_loss: 0.0372 - val_mean_squared_error: 0.0372
# Epoch 61/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0381 - mean_squared_error: 0.0381 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 62/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0380 - mean_squared_error: 0.0380 - val_loss: 0.0370 - val_mean_squared_error: 0.0370
# Epoch 63/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0379 - mean_squared_error: 0.0379 - val_loss: 0.0369 - val_mean_squared_error: 0.0369
# Epoch 64/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0378 - mean_squared_error: 0.0378 - val_loss: 0.0368 - val_mean_squared_error: 0.0368
# Epoch 65/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0376 - mean_squared_error: 0.0376 - val_loss: 0.0366 - val_mean_squared_error: 0.0366
# Epoch 66/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0375 - mean_squared_error: 0.0375 - val_loss: 0.0365 - val_mean_squared_error: 0.0365
# Epoch 67/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0373 - mean_squared_error: 0.0373 - val_loss: 0.0363 - val_mean_squared_error: 0.0363
# Epoch 68/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0362 - val_mean_squared_error: 0.0362
# Epoch 69/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0370 - mean_squared_error: 0.0370 - val_loss: 0.0360 - val_mean_squared_error: 0.0360
# Epoch 70/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0368 - mean_squared_error: 0.0368 - val_loss: 0.0358 - val_mean_squared_error: 0.0358
# Epoch 71/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0366 - mean_squared_error: 0.0366 - val_loss: 0.0355 - val_mean_squared_error: 0.0355
# Epoch 72/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0363 - mean_squared_error: 0.0363 - val_loss: 0.0353 - val_mean_squared_error: 0.0353
# Epoch 73/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0361 - mean_squared_error: 0.0361 - val_loss: 0.0351 - val_mean_squared_error: 0.0351
# Epoch 74/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0358 - mean_squared_error: 0.0358 - val_loss: 0.0348 - val_mean_squared_error: 0.0348
# Epoch 75/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0355 - mean_squared_error: 0.0355 - val_loss: 0.0345 - val_mean_squared_error: 0.0345
# Epoch 76/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0353 - mean_squared_error: 0.0353 - val_loss: 0.0342 - val_mean_squared_error: 0.0342
# Epoch 77/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0349 - mean_squared_error: 0.0349 - val_loss: 0.0339 - val_mean_squared_error: 0.0339
# Epoch 78/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0346 - mean_squared_error: 0.0346 - val_loss: 0.0336 - val_mean_squared_error: 0.0336
# Epoch 79/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0343 - mean_squared_error: 0.0343 - val_loss: 0.0333 - val_mean_squared_error: 0.0333
# Epoch 80/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0339 - mean_squared_error: 0.0339 - val_loss: 0.0329 - val_mean_squared_error: 0.0329
# Epoch 81/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0336 - mean_squared_error: 0.0336 - val_loss: 0.0325 - val_mean_squared_error: 0.0325
# Epoch 82/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0332 - mean_squared_error: 0.0332 - val_loss: 0.0322 - val_mean_squared_error: 0.0322
# Epoch 83/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0328 - mean_squared_error: 0.0328 - val_loss: 0.0318 - val_mean_squared_error: 0.0318
# Epoch 84/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0324 - mean_squared_error: 0.0324 - val_loss: 0.0314 - val_mean_squared_error: 0.0314
# Epoch 85/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0320 - mean_squared_error: 0.0320 - val_loss: 0.0310 - val_mean_squared_error: 0.0310
# Epoch 86/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0315 - mean_squared_error: 0.0315 - val_loss: 0.0305 - val_mean_squared_error: 0.0305
# Epoch 87/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0311 - mean_squared_error: 0.0311 - val_loss: 0.0301 - val_mean_squared_error: 0.0301
# Epoch 88/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0306 - mean_squared_error: 0.0306 - val_loss: 0.0297 - val_mean_squared_error: 0.0297
# Epoch 89/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0302 - mean_squared_error: 0.0302 - val_loss: 0.0292 - val_mean_squared_error: 0.0292
# Epoch 90/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0297 - mean_squared_error: 0.0297 - val_loss: 0.0288 - val_mean_squared_error: 0.0288
# Epoch 91/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0293 - mean_squared_error: 0.0293 - val_loss: 0.0283 - val_mean_squared_error: 0.0283
# Epoch 92/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0288 - mean_squared_error: 0.0288 - val_loss: 0.0279 - val_mean_squared_error: 0.0279
# Epoch 93/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0284 - mean_squared_error: 0.0284 - val_loss: 0.0274 - val_mean_squared_error: 0.0274
# Epoch 94/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0270 - val_mean_squared_error: 0.0270
# Epoch 95/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0275 - mean_squared_error: 0.0275 - val_loss: 0.0266 - val_mean_squared_error: 0.0266
# Epoch 96/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0270 - mean_squared_error: 0.0270 - val_loss: 0.0261 - val_mean_squared_error: 0.0261
# Epoch 97/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0266 - mean_squared_error: 0.0266 - val_loss: 0.0257 - val_mean_squared_error: 0.0257
# Epoch 98/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0261 - mean_squared_error: 0.0261 - val_loss: 0.0253 - val_mean_squared_error: 0.0253
# Epoch 99/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0257 - mean_squared_error: 0.0257 - val_loss: 0.0249 - val_mean_squared_error: 0.0249
# Epoch 100/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0253 - mean_squared_error: 0.0253 - val_loss: 0.0245 - val_mean_squared_error: 0.0245
# Epoch 101/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0249 - mean_squared_error: 0.0249 - val_loss: 0.0241 - val_mean_squared_error: 0.0241
# Epoch 102/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0245 - mean_squared_error: 0.0245 - val_loss: 0.0238 - val_mean_squared_error: 0.0238
# Epoch 103/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.0234 - val_mean_squared_error: 0.0234
# Epoch 104/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0237 - mean_squared_error: 0.0237 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 105/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0227 - val_mean_squared_error: 0.0227
# Epoch 106/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0224 - val_mean_squared_error: 0.0224
# Epoch 107/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0221 - val_mean_squared_error: 0.0221
# Epoch 108/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0218 - val_mean_squared_error: 0.0218
# Epoch 109/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0221 - mean_squared_error: 0.0221 - val_loss: 0.0215 - val_mean_squared_error: 0.0215
# Epoch 110/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0213 - val_mean_squared_error: 0.0213
# Epoch 111/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0216 - mean_squared_error: 0.0216 - val_loss: 0.0210 - val_mean_squared_error: 0.0210
# Epoch 112/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0213 - mean_squared_error: 0.0213 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 113/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0211 - mean_squared_error: 0.0211 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 114/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0209 - mean_squared_error: 0.0209 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 115/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0207 - mean_squared_error: 0.0207 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 116/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0205 - mean_squared_error: 0.0205 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 117/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0203 - mean_squared_error: 0.0203 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 118/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0201 - mean_squared_error: 0.0201 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 119/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 120/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 121/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.0195 - val_mean_squared_error: 0.0195
# Epoch 122/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0196 - mean_squared_error: 0.0196 - val_loss: 0.0194 - val_mean_squared_error: 0.0194
# Epoch 123/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0193 - val_mean_squared_error: 0.0193
# Epoch 124/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0192 - val_mean_squared_error: 0.0192
# Epoch 125/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0191 - val_mean_squared_error: 0.0191
# Epoch 126/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.0191 - val_mean_squared_error: 0.0191
# Epoch 127/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.0190 - val_mean_squared_error: 0.0190
# Epoch 128/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0190 - val_mean_squared_error: 0.0190
# Epoch 129/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0189 - val_mean_squared_error: 0.0189
# Epoch 130/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0189 - val_mean_squared_error: 0.0189
# Epoch 131/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0189 - mean_squared_error: 0.0189 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 132/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0189 - mean_squared_error: 0.0189 - val_loss: 0.0188 - val_mean_squared_error: 0.0188
# Epoch 133/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 134/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 135/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 136/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0187 - mean_squared_error: 0.0187 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 137/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0187 - mean_squared_error: 0.0187 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 138/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0187 - mean_squared_error: 0.0187 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 139/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0186 - val_mean_squared_error: 0.0186
# Epoch 140/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 141/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 142/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 143/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 144/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 145/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 146/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 147/300
# 26/26 [==============================] - 0s 968us/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 148/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 149/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0184 - val_mean_squared_error: 0.0184
# Epoch 150/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 151/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 152/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 153/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 154/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0183 - val_mean_squared_error: 0.0183
# Epoch 155/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0182 - val_mean_squared_error: 0.0182
# Epoch 156/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0182 - val_mean_squared_error: 0.0182
# Epoch 157/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0182 - val_mean_squared_error: 0.0182
# Epoch 158/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0182 - val_mean_squared_error: 0.0182
# Epoch 159/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0182 - val_mean_squared_error: 0.0182
# Epoch 160/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0181 - val_mean_squared_error: 0.0181
# Epoch 161/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0181 - val_mean_squared_error: 0.0181
# Epoch 162/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0181 - val_mean_squared_error: 0.0181
# Epoch 163/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0181 - val_mean_squared_error: 0.0181
# Epoch 164/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0180 - val_mean_squared_error: 0.0180
# Epoch 165/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0180 - val_mean_squared_error: 0.0180
# Epoch 166/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0180 - val_mean_squared_error: 0.0180
# Epoch 167/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0180 - val_mean_squared_error: 0.0180
# Epoch 168/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
# Epoch 169/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
# Epoch 170/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
# Epoch 171/300
# 26/26 [==============================] - 0s 954us/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
# Epoch 172/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
# Epoch 173/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
# Epoch 174/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
# Epoch 175/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0177 - val_mean_squared_error: 0.0177
# Epoch 176/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0177 - val_mean_squared_error: 0.0177
# Epoch 177/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0177 - val_mean_squared_error: 0.0177
# Epoch 178/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 179/300
# 26/26 [==============================] - 0s 970us/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 180/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 181/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 182/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0175 - val_mean_squared_error: 0.0175
# Epoch 183/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0175 - val_mean_squared_error: 0.0175
# Epoch 184/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0175 - val_mean_squared_error: 0.0175
# Epoch 185/300
# 26/26 [==============================] - 0s 997us/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# Epoch 186/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# Epoch 187/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# Epoch 188/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0173 - val_mean_squared_error: 0.0173
# Epoch 189/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0173 - val_mean_squared_error: 0.0173
# Epoch 190/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0173 - val_mean_squared_error: 0.0173
# Epoch 191/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 192/300
# 26/26 [==============================] - 0s 928us/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 193/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0172 - val_mean_squared_error: 0.0172
# Epoch 194/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 195/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 196/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0171 - val_mean_squared_error: 0.0171
# Epoch 197/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 198/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 199/300
# 26/26 [==============================] - 0s 944us/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
# Epoch 200/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 201/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 202/300
# 26/26 [==============================] - 0s 949us/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 203/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 204/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 205/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 206/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 207/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 208/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 209/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 210/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0166 - val_mean_squared_error: 0.0166
# Epoch 211/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 212/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 213/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# Epoch 214/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# Epoch 215/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# Epoch 216/300
# 26/26 [==============================] - 0s 936us/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0163 - val_mean_squared_error: 0.0163
# Epoch 217/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0163 - val_mean_squared_error: 0.0163
# Epoch 218/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0162 - val_mean_squared_error: 0.0162
# Epoch 219/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0162 - val_mean_squared_error: 0.0162
# Epoch 220/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0161 - val_mean_squared_error: 0.0161
# Epoch 221/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0161 - val_mean_squared_error: 0.0161
# Epoch 222/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 223/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 224/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 225/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0159 - val_mean_squared_error: 0.0159
# Epoch 226/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0159 - val_mean_squared_error: 0.0159
# Epoch 227/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0158 - val_mean_squared_error: 0.0158
# Epoch 228/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0158 - val_mean_squared_error: 0.0158
# Epoch 229/300
# 26/26 [==============================] - 0s 884us/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0157 - val_mean_squared_error: 0.0157
# Epoch 230/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0157 - val_mean_squared_error: 0.0157
# Epoch 231/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# Epoch 232/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# Epoch 233/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0155 - val_mean_squared_error: 0.0155
# Epoch 234/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0155 - val_mean_squared_error: 0.0155
# Epoch 235/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0154 - val_mean_squared_error: 0.0154
# Epoch 236/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0154 - val_mean_squared_error: 0.0154
# Epoch 237/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 0.0153 - val_mean_squared_error: 0.0153
# Epoch 238/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 0.0153 - val_mean_squared_error: 0.0153
# Epoch 239/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0153 - val_mean_squared_error: 0.0153
# Epoch 240/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0152 - val_mean_squared_error: 0.0152
# Epoch 241/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.0152 - val_mean_squared_error: 0.0152
# Epoch 242/300
# 26/26 [==============================] - 0s 1000us/step - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.0151 - val_mean_squared_error: 0.0151
# Epoch 243/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0151 - val_mean_squared_error: 0.0151
# Epoch 244/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0150 - val_mean_squared_error: 0.0150
# Epoch 245/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0150 - val_mean_squared_error: 0.0150
# Epoch 246/300
# 26/26 [==============================] - 0s 923us/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0149 - val_mean_squared_error: 0.0149
# Epoch 247/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0149 - val_mean_squared_error: 0.0149
# Epoch 248/300
# 26/26 [==============================] - 0s 961us/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0148 - val_mean_squared_error: 0.0148
# Epoch 249/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0148 - val_mean_squared_error: 0.0148
# Epoch 250/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0148 - val_mean_squared_error: 0.0148
# Epoch 251/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0147 - val_mean_squared_error: 0.0147
# Epoch 252/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0147 - val_mean_squared_error: 0.0147
# Epoch 253/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# Epoch 254/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# Epoch 255/300
# 26/26 [==============================] - 0s 956us/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# Epoch 256/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0145 - val_mean_squared_error: 0.0145
# Epoch 257/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0145 - val_mean_squared_error: 0.0145
# Epoch 258/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0144 - val_mean_squared_error: 0.0144
# Epoch 259/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0144 - val_mean_squared_error: 0.0144
# Epoch 260/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0144 - val_mean_squared_error: 0.0144
# Epoch 261/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0143 - val_mean_squared_error: 0.0143
# Epoch 262/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0143 - val_mean_squared_error: 0.0143
# Epoch 263/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0143 - val_mean_squared_error: 0.0143
# Epoch 264/300
# 26/26 [==============================] - 0s 903us/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0142 - val_mean_squared_error: 0.0142
# Epoch 265/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0142 - val_mean_squared_error: 0.0142
# Epoch 266/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0142 - val_mean_squared_error: 0.0142
# Epoch 267/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0141 - val_mean_squared_error: 0.0141
# Epoch 268/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0141 - val_mean_squared_error: 0.0141
# Epoch 269/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0141 - val_mean_squared_error: 0.0141
# Epoch 270/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0141 - val_mean_squared_error: 0.0141
# Epoch 271/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0140 - val_mean_squared_error: 0.0140
# Epoch 272/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0140 - val_mean_squared_error: 0.0140
# Epoch 273/300
# 26/26 [==============================] - 0s 980us/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0140 - val_mean_squared_error: 0.0140
# Epoch 274/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# Epoch 275/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# Epoch 276/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# Epoch 277/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
# Epoch 278/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
# Epoch 279/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
# Epoch 280/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
# Epoch 281/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
# Epoch 282/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
# Epoch 283/300
# 26/26 [==============================] - 0s 945us/step - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0137 - val_mean_squared_error: 0.0137
# Epoch 284/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0136 - val_mean_squared_error: 0.0136
# Epoch 285/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0136 - val_mean_squared_error: 0.0136
# Epoch 286/300
# 26/26 [==============================] - 0s 951us/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0136 - val_mean_squared_error: 0.0136
# Epoch 287/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0135 - val_mean_squared_error: 0.0135
# Epoch 288/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0135 - val_mean_squared_error: 0.0135
# Epoch 289/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0135 - val_mean_squared_error: 0.0135
# Epoch 290/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0135 - val_mean_squared_error: 0.0135
# Epoch 291/300
# 26/26 [==============================] - 0s 945us/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0134 - val_mean_squared_error: 0.0134
# Epoch 292/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0134 - val_mean_squared_error: 0.0134
# Epoch 293/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0134 - val_mean_squared_error: 0.0134
# Epoch 294/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0133 - val_mean_squared_error: 0.0133
# Epoch 295/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0133 - val_mean_squared_error: 0.0133
# Epoch 296/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0133 - val_mean_squared_error: 0.0133
# Epoch 297/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0133 - val_mean_squared_error: 0.0133
# Epoch 298/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0133 - val_mean_squared_error: 0.0133
# Epoch 299/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0132 - val_mean_squared_error: 0.0132
# Epoch 300/300
# 26/26 [==============================] - 0s 957us/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0132 - val_mean_squared_error: 0.0132

# %% [markdown]
# Now is possible to look at the lower dimensional space representation of our data by detaching the decoder part as follow:

# %%
# Defining Encoder
encoder       = autoencoder.get_layer("Encoder2").output
encoder_model = keras.Model(inputs=autoencoder.input, outputs=encoder)

# %%
xtrain_latent = encoder_model.predict(xSimple_train)[:,0]
ytrain_latent = encoder_model.predict(xSimple_train)[:,1]

fig = plt.figure(figsize=(10,10))
plt.scatter(xtrain_latent, ytrain_latent)
plt.xlabel('X Latent Space', fontsize=15)
plt.ylabel('Y Latent Space', fontsize=15)
plt.title("Training Set Latent representation", fontsize=15)
plt.xticks(fontsize=15);
plt.yticks(fontsize=15);

# %% [markdown]
# In the plot above we can distinguish two cluster. We can assume that:
# 1. The one in the lower-left corner should contain beam data which have homogeneous features.
# 2. The big blob in the upper-part corner presumably contain reaction data.
#
# Let's use kMeans in the latent space in order to classify data in our validation dataset and the let's look at the labels in order to
# make sure that our assumption above holds.

# %%
# Training Clustering k-Means
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, random_state=20).fit(encoder_model.predict(xSimple_train))

# %%
x_latent = encoder_model.predict(xSimple_val)[:, 0]
y_latent = encoder_model.predict(xSimple_val)[:, 1]

list_reac_x = []
list_reac_y = []
list_beam_x = []
list_beam_y = []

for xl,yl,l in zip(x_latent, y_latent, Labels_val) :
    
        if(l==1):
            
            list_reac_x.append(xl)
            list_reac_y.append(yl)
    
        else:
            
            list_beam_x.append(xl)
            list_beam_y.append(yl)
            
centroids = kmeans.cluster_centers_

# Draw Background class regions
points = np.random.uniform(-1,1,(10,2))

p_reac_x = []
p_reac_y = []
p_beam_x = []
p_beam_y = []

for x in np.arange(-1, 1, 0.01):
    
    for y in np.arange(-1, 1, 0.01):
    
        p = np.array([x,y], dtype=np.float32).reshape(1,-1)

        if(kmeans.predict(p) == 1):

            p_reac_x.append(p[0][0])
            p_reac_y.append(p[0][1])
            
        else:            
            
            p_beam_x.append(p[0][0])
            p_beam_y.append(p[0][1])


# Scoring Clustering Results
l00 = 0
l01 = 0
l10 = 0
l11 = 0

misclassified = []

for i, (xl, yl, l) in enumerate(zip(x_latent, y_latent, Labels_val)):

    predicted_label = kmeans.predict(np.array([xl,yl], dtype=np.float32).reshape(1,-1))
    
    if(predicted_label == 0 and l == 0):
        l00 += 1
    if(predicted_label == 0 and l == 1):
        l01 += 1
        misclassified.append(i)
    if(predicted_label == 1 and l == 0):
        l10 += 1
        misclassified.append(i)
    if(predicted_label == 1 and l == 1):
        l11 += 1
    
# Compute the Confusion Matrix
cm = np.matrix([[l00/(l00+l10),l01/(l11+l01)],[l10/(l10+l00),l11/(l01+l11)]])
    
fig, ax = plt.subplots(figsize=(10,10))
im = ax.imshow(cm, cmap='copper')

ax.set_xticks(np.arange(len(['beam', 'reaction'])))
ax.set_yticks(np.arange(len(['beam', 'reaction'])))

ax.set_xticklabels(['beam', 'reaction'])
ax.set_yticklabels(['beam', 'reaction'])

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.ylabel("Predicted Class", fontsize=20)
plt.xlabel("True Class", fontsize=20)

for i in range(len(['beam','reaction'])):
    for j in range(len(['beam', 'reaction'])):
        text = ax.text(j, i, np.round(cm[i, j],3),
                       ha="center", va="center", color="w", fontsize=25)

# Visualizing Results
fig = plt.figure(figsize=(10,10))
plt.scatter(p_reac_x, p_reac_y, color='gray', marker='s', s=5, alpha=0.15)
plt.scatter(p_beam_x, p_beam_y, color='red', marker='s', s=5, alpha=0.15)
plt.scatter(list_reac_x, list_reac_y, color='gray', label='Reaction', alpha=0.5)
plt.scatter(list_beam_x, list_beam_y, color='red', label='Beam', alpha=0.5)
plt.scatter([centroids[0][0]],[centroids[0][1]], marker='*', s=500, c='white')
plt.scatter([centroids[1][0]],[centroids[1][1]], marker='*', s=500, c='white')


plt.legend(fontsize=20);
plt.title("Validation Set Clustering in Latent Space", fontsize=20);
plt.xticks(fontsize=20);
plt.xlabel("Latent Space X", fontsize=20);
plt.yticks(fontsize=20);
plt.ylabel("Latent Space Y", fontsize=20);

# %% [markdown]
# In the plot above is possibile to see that our initial guess about the clusters is indeed valid.
